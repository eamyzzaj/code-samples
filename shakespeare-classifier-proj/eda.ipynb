# %%
import nltk
import eda_utils as eda_utils
import pandas as pd

dream = nltk.corpus.shakespeare.xml("dream.xml")
hamlet = nltk.corpus.shakespeare.xml("hamlet.xml")
macbeth = nltk.corpus.shakespeare.xml("macbeth.xml")
randj = nltk.corpus.shakespeare.xml("r_and_j.xml") 

andc = nltk.corpus.shakespeare.xml("a_and_c.xml") 
jcaesar = nltk.corpus.shakespeare.xml("j_caesar.xml") 
merchant = nltk.corpus.shakespeare.xml("merchant.xml") 
othello = nltk.corpus.shakespeare.xml("othello.xml") 

works = [ 
    {"work_xml": dream}, 
    {"work_xml": hamlet}, 
    {"work_xml": macbeth}, 
    {"work_xml": randj},
    {"work_xml": andc},
    {"work_xml": jcaesar},
    {"work_xml": merchant},
    {"work_xml": othello}
    ]

for w in works:
    eda_utils.extract_title_xml(w)
    main, side = eda_utils.extract_charcs_xml(w["work_xml"], print_charcs=False )
    w["main_charcs"] = main
    w["side_charcs"] = side

    w["parsed_play"] = eda_utils.parse_play_xml(w["work_xml"])

    w["merged"] = eda_utils.merge_play_data(w["parsed_play"], w["main_charcs"], w["side_charcs"])


all_data = []
for w in works:
    xml_tree = w["work_xml"]
    main, side = eda_utils.extract_charcs_xml(xml_tree, print_charcs=False)
    parsed = eda_utils.parse_play_xml(xml_tree)
    merged = eda_utils.merge_play_data(parsed, main, side)
    stats = eda_utils.summarize_play_stats(merged, main, side)
    df = stats["character_df"]  # extract the actual DataFrame
    all_data.append(df)


# --- Combine and export ---
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("../csv/all_plays_char_stats.csv", index=False)
# Out:
# A Midsummer Night's Dream
# ============================
# Acts: 5 | Scenes: 9 | Total Speeches: 500 | Total Lines: 2159
# Main: 21 | Side: 2 | Ratio: 21:2
#
# Act-level speech totals:
#   Act 1: 90 speeches
#   Act 2: 62 speeches
#   Act 3: 180 speeches
#   Act 4: 64 speeches
#   Act 5: 104 speeches
#
# Top 10 characters by line count:
#                      play character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# A Midsummer Night's Dream   THESEUS              48          233                3              3               9.6           10.79                   16.00                  4.85       4.85          16.00      10.79  77.67     0.33                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream    HELENA              36          229                5              4               7.2           10.61                    7.20                  6.36       6.36           7.20      10.61  57.25     0.56                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream    OBERON              29          226                5              4               5.8           10.47                    5.80                  7.79       7.79           5.80      10.47  56.50     0.56                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream      PUCK              33          209                6              4               6.6            9.68                    5.50                  6.33       6.33           5.50       9.68  52.25     0.67                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream    BOTTOM              50          204                5              4              10.0            9.45                   10.00                  4.08       4.08          10.00       9.45  51.00     0.56                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream  LYSANDER              50          178                5              5              10.0            8.24                   10.00                  3.56       3.56          10.00       8.24  35.60     0.56                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream    HERMIA              47          165                4              4               9.4            7.64                   11.75                  3.51       3.51          11.75       7.64  41.25     0.44                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream   TITANIA              23          158                5              4               4.6            7.32                    4.60                  6.87       6.87           4.60       7.32  39.50     0.56                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream DEMETRIUS              48          134                6              5               9.6            6.21                    8.00                  2.79       2.79           8.00       6.21  26.80     0.67                5                  9                  500              2159            21:2      main
# A Midsummer Night's Dream    QUINCE              38           83                3              3               7.6            3.84                   12.67                  2.18       2.18          12.67       3.84  27.67     0.33                5                  9                  500              2159            21:2      main
#
# The Tragedy of Hamlet, Prince of Denmark
# ===========================================
# Acts: 5 | Scenes: 20 | Total Speeches: 1150 | Total Lines: 4026
# Main: 21 | Side: 5 | Ratio: 21:5
#
# Act-level speech totals:
#   Act 1: 259 speeches
#   Act 2: 202 speeches
#   Act 3: 252 speeches
#   Act 4: 180 speeches
#   Act 5: 257 speeches
#
# Top 10 characters by line count:
#                                     play      character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Hamlet, Prince of Denmark         HAMLET             359         1495               13              5             31.22           37.13                   27.62                  4.16       4.16          27.62      37.13 299.00     0.65                5                 20                 1150              4026            21:5      main
# The Tragedy of Hamlet, Prince of Denmark  KING CLAUDIUS             102          550               11              5              8.87           13.66                    9.27                  5.39       5.39           9.27      13.66 110.00     0.55                5                 20                 1150              4026            21:5      side
# The Tragedy of Hamlet, Prince of Denmark  LORD POLONIUS              86          355                8              3              7.48            8.82                   10.75                  4.13       4.13          10.75       8.82 118.33     0.40                5                 20                 1150              4026            21:5      side
# The Tragedy of Hamlet, Prince of Denmark        HORATIO             112          291                9              4              9.74            7.23                   12.44                  2.60       2.60          12.44       7.23  72.75     0.45                5                 20                 1150              4026            21:5      main
# The Tragedy of Hamlet, Prince of Denmark        LAERTES              62          206                6              3              5.39            5.12                   10.33                  3.32       3.32          10.33       5.12  68.67     0.30                5                 20                 1150              4026            21:5      main
# The Tragedy of Hamlet, Prince of Denmark        OPHELIA              58          173                5              4              5.04            4.30                   11.60                  2.98       2.98          11.60       4.30  43.25     0.25                5                 20                 1150              4026            21:5      main
# The Tragedy of Hamlet, Prince of Denmark QUEEN GERTRUDE              69          157               10              5              6.00            3.90                    6.90                  2.28       2.28           6.90       3.90  31.40     0.50                5                 20                 1150              4026            21:5      side
# The Tragedy of Hamlet, Prince of Denmark    ROSENCRANTZ              49           97                7              3              4.26            2.41                    7.00                  1.98       1.98           7.00       2.41  32.33     0.35                5                 20                 1150              4026            21:5      main
# The Tragedy of Hamlet, Prince of Denmark          GHOST              14           95                2              2              1.22            2.36                    7.00                  6.79       6.79           7.00       2.36  47.50     0.10                5                 20                 1150              4026            21:5      side
# The Tragedy of Hamlet, Prince of Denmark    FIRST CLOWN              33           93                1              1              2.87            2.31                   33.00                  2.82       2.82          33.00       2.31  93.00     0.05                5                 20                 1150              4026            21:5      side
#
# The Tragedy of Macbeth
# =========================
# Acts: 5 | Scenes: 28 | Total Speeches: 650 | Total Lines: 2386
# Main: 21 | Side: 5 | Ratio: 21:5
#
# Act-level speech totals:
#   Act 1: 121 speeches
#   Act 2: 120 speeches
#   Act 3: 128 speeches
#   Act 4: 159 speeches
#   Act 5: 122 speeches
#
# Top 10 characters by line count:
#                   play    character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Macbeth      MACBETH             146          719               15              5             22.46           30.13                    9.73                  4.92       4.92           9.73      30.13 143.80     0.54                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth LADY MACBETH              59          265                9              4              9.08           11.11                    6.56                  4.49       4.49           6.56      11.11  66.25     0.32                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth      MALCOLM              40          212                8              4              6.15            8.89                    5.00                  5.30       5.30           5.00       8.89  53.00     0.29                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth      MACDUFF              59          180                7              3              9.08            7.54                    8.43                  3.05       3.05           8.43       7.54  60.00     0.25                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth         ROSS              39          135                7              5              6.00            5.66                    5.57                  3.46       3.46           5.57       5.66  27.00     0.25                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth       BANQUO              33          113                7              3              5.08            4.74                    4.71                  3.42       3.42           4.71       4.74  37.67     0.25                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth       LENNOX              22           74                6              5              3.38            3.10                    3.67                  3.36       3.36           3.67       3.10  14.80     0.21                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth       DUNCAN              18           70                3              1              2.77            2.93                    6.00                  3.89       3.89           6.00       2.93  70.00     0.11                5                 28                  650              2386            21:5      main
# The Tragedy of Macbeth  FIRST WITCH              23           62                4              3              3.54            2.60                    5.75                  2.70       2.70           5.75       2.60  20.67     0.14                5                 28                  650              2386            21:5      side
# The Tragedy of Macbeth       PORTER               4           46                1              1              0.62            1.93                    4.00                 11.50      11.50           4.00       1.93  46.00     0.04                5                 28                  650              2386            21:5      side
#
# The Tragedy of Romeo and Juliet
# ==================================
# Acts: 5 | Scenes: 24 | Total Speeches: 839 | Total Lines: 3065
# Main: 18 | Side: 7 | Ratio: 18:7
#
# Act-level speech totals:
#   Act 1: 235 speeches
#   Act 2: 204 speeches
#   Act 3: 197 speeches
#   Act 4: 115 speeches
#   Act 5: 88 speeches
#
# Top 10 characters by line count:
#                            play      character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance   focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Romeo and Juliet          ROMEO             163          612               14              4            19.430           19.97                  11.640                 3.750      3.750         11.640      19.97 153.000     0.58                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet         JULIET             118          544               11              5            14.060           17.75                  10.730                 4.610      4.610         10.730      17.75 108.800     0.46                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet FRIAR LAURENCE              55          351                7              4             6.560           11.45                   7.860                 6.380      6.380          7.860      11.45  87.750     0.29                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet          NURSE              90          281               12              4             5.365            4.58                   4.545                 6.030      6.030          4.545       4.58  38.500     0.25                5                 24                  839              3065            18:7      side
# The Tragedy of Romeo and Juliet        CAPULET              50          273                9              4             5.960            8.91                   5.560                 5.460      5.460          5.560       8.91  68.250     0.38                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet       MERCUTIO              62          261                4              3             7.390            8.52                  15.500                 4.210      4.210         15.500       8.52  87.000     0.17                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet       BENVOLIO              64          160                7              3             7.630            5.22                   9.140                 2.500      2.500          9.140       5.22  53.330     0.29                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet   LADY CAPULET              45          115               11              4             2.680            1.88                   2.700                 2.285      2.285          2.700       1.88  15.125     0.23                5                 24                  839              3065            18:7      main
# The Tragedy of Romeo and Juliet         PRINCE              16           76                3              3             1.910            2.48                   5.330                 4.750      4.750          5.330       2.48  25.330     0.12                5                 24                  839              3065            18:7      side
# The Tragedy of Romeo and Juliet          PARIS              23           70                5              4             2.740            2.28                   4.600                 3.040      3.040          4.600       2.28  17.500     0.21                5                 24                  839              3065            18:7      main
#
# The Tragedy of Antony and Cleopatra
# ======================================
# Acts: 5 | Scenes: 42 | Total Speeches: 1179 | Total Lines: 3565
# Main: 33 | Side: 1 | Ratio: 33:1
#
# Act-level speech totals:
#   Act 1: 196 speeches
#   Act 2: 325 speeches
#   Act 3: 293 speeches
#   Act 4: 211 speeches
#   Act 5: 154 speeches
#
# Top 10 characters by line count:
#                                play          character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Antony and Cleopatra        MARK ANTONY             204          851               22              4             17.30           23.87                    9.27                  4.17       4.17           9.27      23.87 212.75     0.52                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra          CLEOPATRA             204          686               16              5             17.30           19.24                   12.75                  3.36       3.36          12.75      19.24 137.20     0.38                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra    OCTAVIUS CAESAR              98          421               14              5              8.31           11.81                    7.00                  4.30       4.30           7.00      11.81  84.20     0.33                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra DOMITIUS ENOBARBUS             113          355               12              4              9.58            9.96                    9.42                  3.14       3.14           9.42       9.96  88.75     0.29                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra             POMPEY              41          140                3              1              3.48            3.93                   13.67                  3.41       3.41          13.67       3.93 140.00     0.07                5                 42                 1179              3565            33:1      side
# The Tragedy of Antony and Cleopatra           CHARMIAN              63          105               10              5              5.34            2.95                    6.30                  1.67       1.67           6.30       2.95  21.00     0.24                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra          MESSENGER              42           78                6              4              3.56            2.19                    7.00                  1.86       1.86           7.00       2.19  19.50     0.14                5                 42                 1179              3565            33:1      side
# The Tragedy of Antony and Cleopatra            LEPIDUS              32           68                6              3              2.71            1.91                    5.33                  2.12       2.12           5.33       1.91  22.67     0.14                5                 42                 1179              3565            33:1      side
# The Tragedy of Antony and Cleopatra              MENAS              35           64                3              1              2.97            1.80                   11.67                  1.83       1.83          11.67       1.80  64.00     0.07                5                 42                 1179              3565            33:1      main
# The Tragedy of Antony and Cleopatra            AGRIPPA              29           61                7              4              2.46            1.71                    4.14                  2.10       2.10           4.14       1.71  15.25     0.17                5                 42                 1179              3565            33:1      main
#
# The Tragedy of Julius Caesar
# ===============================
# Acts: 5 | Scenes: 18 | Total Speeches: 798 | Total Lines: 2599
# Main: 33 | Side: 2 | Ratio: 33:2
#
# Act-level speech totals:
#   Act 1: 142 speeches
#   Act 2: 137 speeches
#   Act 3: 206 speeches
#   Act 4: 188 speeches
#   Act 5: 125 speeches
#
# Top 10 characters by line count:
#                         play     character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Julius Caesar        BRUTUS             194          728               12              5             24.31           28.01                   16.17                  3.75       3.75          16.17      28.01 145.60     0.67                5                 18                  798              2599            33:2      side
# The Tragedy of Julius Caesar       CASSIUS             140          525                8              5             17.54           20.20                   17.50                  3.75       3.75          17.50      20.20 105.00     0.44                5                 18                  798              2599            33:2      main
# The Tragedy of Julius Caesar        ANTONY              51          329                8              5              6.39           12.66                    6.38                  6.45       6.45           6.38      12.66  65.80     0.44                5                 18                  798              2599            33:2      side
# The Tragedy of Julius Caesar        CAESAR              39          135                3              3              4.89            5.19                   13.00                  3.46       3.46          13.00       5.19  45.00     0.17                5                 18                  798              2599            33:2      side
# The Tragedy of Julius Caesar         CASCA              39          133                4              3              4.89            5.12                    9.75                  3.41       3.41           9.75       5.12  44.33     0.22                5                 18                  798              2599            33:2      main
# The Tragedy of Julius Caesar        PORTIA              16           92                2              1              2.01            3.54                    8.00                  5.75       5.75           8.00       3.54  92.00     0.11                5                 18                  798              2599            33:2      main
# The Tragedy of Julius Caesar      OCTAVIUS              19           46                3              2              2.38            1.77                    6.33                  2.42       2.42           6.33       1.77  23.00     0.17                5                 18                  798              2599            33:2      side
# The Tragedy of Julius Caesar DECIUS BRUTUS              12           44                3              2              1.50            1.69                    4.00                  3.67       3.67           4.00       1.69  22.00     0.17                5                 18                  798              2599            33:2      main
# The Tragedy of Julius Caesar       MESSALA              21           39                4              2              2.63            1.50                    5.25                  1.86       1.86           5.25       1.50  19.50     0.22                5                 18                  798              2599            33:2      main
# The Tragedy of Julius Caesar        LUCIUS              24           33                3              2              3.01            1.27                    8.00                  1.38       1.38           8.00       1.27  16.50     0.17                5                 18                  798              2599            33:2      main
#
# The Merchant of Venice
# =========================
# Acts: 5 | Scenes: 20 | Total Speeches: 636 | Total Lines: 2663
# Main: 17 | Side: 5 | Ratio: 17:5
#
# Act-level speech totals:
#   Act 1: 107 speeches
#   Act 2: 161 speeches
#   Act 3: 136 speeches
#   Act 4: 142 speeches
#   Act 5: 90 speeches
#
# Top 10 characters by line count:
#                   play character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Merchant of Venice    PORTIA             117          588                9              5             18.40           22.08                   13.00                  5.03       5.03          13.00      22.08 117.60     0.45                5                 20                  636              2663            17:5      main
# The Merchant of Venice   SHYLOCK              79          355                5              4             12.42           13.33                   15.80                  4.49       4.49          15.80      13.33  88.75     0.25                5                 20                  636              2663            17:5      main
# The Merchant of Venice  BASSANIO              73          336                6              5             11.48           12.62                   12.17                  4.60       4.60          12.17      12.62  67.20     0.30                5                 20                  636              2663            17:5      main
# The Merchant of Venice   ANTONIO              47          188                6              5              7.39            7.06                    7.83                  4.00       4.00           7.83       7.06  37.60     0.30                5                 20                  636              2663            17:5      main
# The Merchant of Venice   LORENZO              47          179                7              4              7.39            6.72                    6.71                  3.81       3.81           6.71       6.72  44.75     0.35                5                 20                  636              2663            17:5      main
# The Merchant of Venice  GRATIANO              48          175                8              5              7.55            6.57                    6.00                  3.65       3.65           6.00       6.57  35.00     0.40                5                 20                  636              2663            17:5      main
# The Merchant of Venice LAUNCELOT              44          168                6              3              6.92            6.31                    7.33                  3.82       3.82           7.33       6.31  56.00     0.30                5                 20                  636              2663            17:5      side
# The Merchant of Venice  SALARINO              27          104                6              3              4.25            3.91                    4.50                  3.85       3.85           4.50       3.91  34.67     0.30                5                 20                  636              2663            17:5      main
# The Merchant of Venice   MOROCCO               7          103                2              1              1.10            3.87                    3.50                 14.71      14.71           3.50       3.87 103.00     0.10                5                 20                  636              2663            17:5      side
# The Merchant of Venice   JESSICA              26           86                7              3              4.09            3.23                    3.71                  3.31       3.31           3.71       3.23  28.67     0.35                5                 20                  636              2663            17:5      main
#
# The Tragedy of Othello, the Moor of Venice
# =============================================
# Acts: 5 | Scenes: 15 | Total Speeches: 1183 | Total Lines: 3558
# Main: 11 | Side: 3 | Ratio: 11:3
#
# Act-level speech totals:
#   Act 1: 165 speeches
#   Act 2: 185 speeches
#   Act 3: 285 speeches
#   Act 4: 292 speeches
#   Act 5: 256 speeches
#
# Top 10 characters by line count:
#                                       play      character  total_speeches  total_lines  scenes_appeared  acts_appeared  speech_share_pct  line_share_pct  avg_speeches_per_scene  avg_lines_per_speech  verbosity  talkativeness  dominance  focus  breadth  play_total_acts  play_total_scenes  play_total_speeches  play_total_lines main_side_ratio role_type
# The Tragedy of Othello, the Moor of Venice           IAGO             272         1097               13              5             22.99           30.83                   20.92                  4.03       4.03          20.92      30.83 219.40     0.87                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice        OTHELLO             274          887               12              5             23.16           24.93                   22.83                  3.24       3.24          22.83      24.93 177.40     0.80                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice      DESDEMONA             165          388                9              5             13.95           10.91                   18.33                  2.35       2.35          18.33      10.91  77.60     0.60                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice         CASSIO             111          278                9              5              9.38            7.81                   12.33                  2.50       2.50          12.33       7.81  55.60     0.60                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice         EMILIA             103          245                8              4              8.71            6.89                   12.88                  2.38       2.38          12.88       6.89  61.25     0.53                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice      BRABANTIO              30          139                3              1              2.54            3.91                   10.00                  4.63       4.63          10.00       3.91 139.00     0.20                5                 15                 1183              3558            11:3      side
# The Tragedy of Othello, the Moor of Venice       RODERIGO              59          114                7              4              4.99            3.20                    8.43                  1.93       1.93           8.43       3.20  28.50     0.47                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice       LODOVICO              33           76                4              2              2.79            2.14                    8.25                  2.30       2.30           8.25       2.14  38.00     0.27                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice DUKE OF VENICE              25           73                1              1              2.11            2.05                   25.00                  2.92       2.92          25.00       2.05  73.00     0.07                5                 15                 1183              3558            11:3      main
# The Tragedy of Othello, the Moor of Venice        MONTANO              24           61                3              2              2.03            1.71                    8.00                  2.54       2.54           8.00       1.71  30.50     0.20                5                 15                 1183              3558            11:3      main

# %%
for p in randj.iter():
    print(p.tag, p.text)
# Out:
# PLAY
#
# TITLE The Tragedy of Romeo and Juliet
# FM
#
# P Text placed in the public domain by Moby Lexical Tools, 1992.
# P XML markup by Jon Bosak, 1996-1998.
# P XML Styling done by Ajay Juneja, 1999.
# P This work may be freely copied and distributed worldwide.
# PERSONAE
#
# TITLE Dramatis Personae
# PERSONA ESCALUS, prince of Verona.
# PERSONA PARIS, a young nobleman, kinsman to the prince.
# PGROUP
#
# PERSONA MONTAGUE
# PERSONA CAPULET
# GRPDESCR heads of two houses at variance with each other.
# PERSONA An old man, cousin to Capulet.
# PERSONA ROMEO, son to Montague.
# PERSONA MERCUTIO, kinsman to the prince, and friend to Romeo.
# PERSONA BENVOLIO, nephew to Montague, and friend to Romeo.
# PERSONA TYBALT, nephew to Lady Capulet.
# PGROUP
#
# PERSONA FRIAR LAURENCE
# PERSONA FRIAR JOHN
# GRPDESCR Franciscans.
# PERSONA BALTHASAR, servant to Romeo.
# PGROUP
#
# PERSONA SAMPSON
# PERSONA GREGORY
# GRPDESCR servants to Capulet.
# PERSONA PETER, servant to Juliet's nurse.
# PERSONA ABRAHAM, servant to Montague.
# PERSONA An Apothecary.
# PERSONA Three Musicians.
# PERSONA Page to Paris; another Page; an officer.
# PERSONA LADY MONTAGUE, wife to Montague.
# PERSONA LADY CAPULET, wife to Capulet.
# PERSONA JULIET, daughter to Capulet.
# PERSONA Nurse to Juliet.
# PERSONA Citizens of Verona; several Men and Women, relations to both houses; Maskers, Guards, Watchmen, and Attendants.
# PERSONA Chorus.
# SCNDESCR SCENE  Verona: Mantua.
# PLAYSUBT ROMEO AND JULIET
# ACT None
# TITLE ACT I
# PROLOGUE None
# TITLE PROLOGUE
# SPEECH None
# SPEAKER None
# LINE Two households, both alike in dignity,
# LINE In fair Verona, where we lay our scene,
# LINE From ancient grudge break to new mutiny,
# LINE Where civil blood makes civil hands unclean.
# LINE From forth the fatal loins of these two foes
# LINE A pair of star-cross'd lovers take their life;
# LINE Whole misadventured piteous overthrows
# LINE Do with their death bury their parents' strife.
# LINE The fearful passage of their death-mark'd love,
# LINE And the continuance of their parents' rage,
# LINE Which, but their children's end, nought could remove,
# LINE Is now the two hours' traffic of our stage;
# LINE The which if you with patient ears attend,
# LINE What here shall miss, our toil shall strive to mend.
# SCENE None
# TITLE SCENE I.  Verona. A public place.
# STAGEDIR Enter SAMPSON and GREGORY, of the house of Capulet,
# armed with swords and bucklers
# SPEECH
#
# SPEAKER SAMPSON
# LINE Gregory, o' my word, we'll not carry coals.
# SPEECH
#
# SPEAKER GREGORY
# LINE No, for then we should be colliers.
# SPEECH
#
# SPEAKER SAMPSON
# LINE I mean, an we be in choler, we'll draw.
# SPEECH
#
# SPEAKER GREGORY
# LINE Ay, while you live, draw your neck out o' the collar.
# SPEECH
#
# SPEAKER SAMPSON
# LINE I strike quickly, being moved.
# SPEECH
#
# SPEAKER GREGORY
# LINE But thou art not quickly moved to strike.
# SPEECH
#
# SPEAKER SAMPSON
# LINE A dog of the house of Montague moves me.
# SPEECH
#
# SPEAKER GREGORY
# LINE To move is to stir; and to be valiant is to stand:
# LINE therefore, if thou art moved, thou runn'st away.
# SPEECH
#
# SPEAKER SAMPSON
# LINE A dog of that house shall move me to stand: I will
# LINE take the wall of any man or maid of Montague's.
# SPEECH
#
# SPEAKER GREGORY
# LINE That shows thee a weak slave; for the weakest goes
# LINE to the wall.
# SPEECH
#
# SPEAKER SAMPSON
# LINE True; and therefore women, being the weaker vessels,
# LINE are ever thrust to the wall: therefore I will push
# LINE Montague's men from the wall, and thrust his maids
# LINE to the wall.
# SPEECH
#
# SPEAKER GREGORY
# LINE The quarrel is between our masters and us their men.
# SPEECH
#
# SPEAKER SAMPSON
# LINE 'Tis all one, I will show myself a tyrant: when I
# LINE have fought with the men, I will be cruel with the
# LINE maids, and cut off their heads.
# SPEECH
#
# SPEAKER GREGORY
# LINE The heads of the maids?
# SPEECH
#
# SPEAKER SAMPSON
# LINE Ay, the heads of the maids, or their maidenheads;
# LINE take it in what sense thou wilt.
# SPEECH
#
# SPEAKER GREGORY
# LINE They must take it in sense that feel it.
# SPEECH
#
# SPEAKER SAMPSON
# LINE Me they shall feel while I am able to stand: and
# LINE 'tis known I am a pretty piece of flesh.
# SPEECH
#
# SPEAKER GREGORY
# LINE 'Tis well thou art not fish; if thou hadst, thou
# LINE hadst been poor John. Draw thy tool! here comes
# LINE two of the house of the Montagues.
# SPEECH
#
# SPEAKER SAMPSON
# LINE My naked weapon is out: quarrel, I will back thee.
# SPEECH
#
# SPEAKER GREGORY
# LINE How! turn thy back and run?
# SPEECH
#
# SPEAKER SAMPSON
# LINE Fear me not.
# SPEECH
#
# SPEAKER GREGORY
# LINE No, marry; I fear thee!
# SPEECH
#
# SPEAKER SAMPSON
# LINE Let us take the law of our sides; let them begin.
# SPEECH
#
# SPEAKER GREGORY
# LINE I will frown as I pass by, and let them take it as
# LINE they list.
# SPEECH
#
# SPEAKER SAMPSON
# LINE Nay, as they dare. I will bite my thumb at them;
# LINE which is a disgrace to them, if they bear it.
# STAGEDIR Enter ABRAHAM and BALTHASAR
# SPEECH
#
# SPEAKER ABRAHAM
# LINE Do you bite your thumb at us, sir?
# SPEECH
#
# SPEAKER SAMPSON
# LINE I do bite my thumb, sir.
# SPEECH
#
# SPEAKER ABRAHAM
# LINE Do you bite your thumb at us, sir?
# SPEECH
#
# SPEAKER SAMPSON
# LINE None
# STAGEDIR Aside to GREGORY
# LINE ay?
# SPEECH
#
# SPEAKER GREGORY
# LINE No.
# SPEECH
#
# SPEAKER SAMPSON
# LINE No, sir, I do not bite my thumb at you, sir, but I
# LINE bite my thumb, sir.
# SPEECH
#
# SPEAKER GREGORY
# LINE Do you quarrel, sir?
# SPEECH
#
# SPEAKER ABRAHAM
# LINE Quarrel sir! no, sir.
# SPEECH
#
# SPEAKER SAMPSON
# LINE If you do, sir, I am for you: I serve as good a man as you.
# SPEECH
#
# SPEAKER ABRAHAM
# LINE No better.
# SPEECH
#
# SPEAKER SAMPSON
# LINE Well, sir.
# SPEECH
#
# SPEAKER GREGORY
# LINE Say 'better:' here comes one of my master's kinsmen.
# SPEECH
#
# SPEAKER SAMPSON
# LINE Yes, better, sir.
# SPEECH
#
# SPEAKER ABRAHAM
# LINE You lie.
# SPEECH
#
# SPEAKER SAMPSON
# LINE Draw, if you be men. Gregory, remember thy swashing blow.
# STAGEDIR They fight
# STAGEDIR Enter BENVOLIO
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Part, fools!
# LINE Put up your swords; you know not what you do.
# STAGEDIR Beats down their swords
# STAGEDIR Enter TYBALT
# SPEECH
#
# SPEAKER TYBALT
# LINE What, art thou drawn among these heartless hinds?
# LINE Turn thee, Benvolio, look upon thy death.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE I do but keep the peace: put up thy sword,
# LINE Or manage it to part these men with me.
# SPEECH
#
# SPEAKER TYBALT
# LINE What, drawn, and talk of peace! I hate the word,
# LINE As I hate hell, all Montagues, and thee:
# LINE Have at thee, coward!
# STAGEDIR They fight
# STAGEDIR Enter, several of both houses, who join the fray;
# then enter Citizens, with clubs
# SPEECH
#
# SPEAKER First Citizen
# LINE Clubs, bills, and partisans! strike! beat them down!
# LINE Down with the Capulets! down with the Montagues!
# STAGEDIR Enter CAPULET in his gown, and LADY CAPULET
# SPEECH
#
# SPEAKER CAPULET
# LINE What noise is this? Give me my long sword, ho!
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE A crutch, a crutch! why call you for a sword?
# SPEECH
#
# SPEAKER CAPULET
# LINE My sword, I say! Old Montague is come,
# LINE And flourishes his blade in spite of me.
# STAGEDIR Enter MONTAGUE and LADY MONTAGUE
# SPEECH
#
# SPEAKER MONTAGUE
# LINE Thou villain Capulet,--Hold me not, let me go.
# SPEECH
#
# SPEAKER LADY MONTAGUE
# LINE Thou shalt not stir a foot to seek a foe.
# STAGEDIR Enter PRINCE, with Attendants
# SPEECH
#
# SPEAKER PRINCE
# LINE Rebellious subjects, enemies to peace,
# LINE Profaners of this neighbour-stained steel,--
# LINE Will they not hear? What, ho! you men, you beasts,
# LINE That quench the fire of your pernicious rage
# LINE With purple fountains issuing from your veins,
# LINE On pain of torture, from those bloody hands
# LINE Throw your mistemper'd weapons to the ground,
# LINE And hear the sentence of your moved prince.
# LINE Three civil brawls, bred of an airy word,
# LINE By thee, old Capulet, and Montague,
# LINE Have thrice disturb'd the quiet of our streets,
# LINE And made Verona's ancient citizens
# LINE Cast by their grave beseeming ornaments,
# LINE To wield old partisans, in hands as old,
# LINE Canker'd with peace, to part your canker'd hate:
# LINE If ever you disturb our streets again,
# LINE Your lives shall pay the forfeit of the peace.
# LINE For this time, all the rest depart away:
# LINE You Capulet; shall go along with me:
# LINE And, Montague, come you this afternoon,
# LINE To know our further pleasure in this case,
# LINE To old Free-town, our common judgment-place.
# LINE Once more, on pain of death, all men depart.
# STAGEDIR Exeunt all but MONTAGUE, LADY MONTAGUE, and BENVOLIO
# SPEECH
#
# SPEAKER MONTAGUE
# LINE Who set this ancient quarrel new abroach?
# LINE Speak, nephew, were you by when it began?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Here were the servants of your adversary,
# LINE And yours, close fighting ere I did approach:
# LINE I drew to part them: in the instant came
# LINE The fiery Tybalt, with his sword prepared,
# LINE Which, as he breathed defiance to my ears,
# LINE He swung about his head and cut the winds,
# LINE Who nothing hurt withal hiss'd him in scorn:
# LINE While we were interchanging thrusts and blows,
# LINE Came more and more and fought on part and part,
# LINE Till the prince came, who parted either part.
# SPEECH
#
# SPEAKER LADY MONTAGUE
# LINE O, where is Romeo? saw you him to-day?
# LINE Right glad I am he was not at this fray.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Madam, an hour before the worshipp'd sun
# LINE Peer'd forth the golden window of the east,
# LINE A troubled mind drave me to walk abroad;
# LINE Where, underneath the grove of sycamore
# LINE That westward rooteth from the city's side,
# LINE So early walking did I see your son:
# LINE Towards him I made, but he was ware of me
# LINE And stole into the covert of the wood:
# LINE I, measuring his affections by my own,
# LINE That most are busied when they're most alone,
# LINE Pursued my humour not pursuing his,
# LINE And gladly shunn'd who gladly fled from me.
# SPEECH
#
# SPEAKER MONTAGUE
# LINE Many a morning hath he there been seen,
# LINE With tears augmenting the fresh morning dew.
# LINE Adding to clouds more clouds with his deep sighs;
# LINE But all so soon as the all-cheering sun
# LINE Should in the furthest east begin to draw
# LINE The shady curtains from Aurora's bed,
# LINE Away from the light steals home my heavy son,
# LINE And private in his chamber pens himself,
# LINE Shuts up his windows, locks far daylight out
# LINE And makes himself an artificial night:
# LINE Black and portentous must this humour prove,
# LINE Unless good counsel may the cause remove.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE My noble uncle, do you know the cause?
# SPEECH
#
# SPEAKER MONTAGUE
# LINE I neither know it nor can learn of him.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Have you importuned him by any means?
# SPEECH
#
# SPEAKER MONTAGUE
# LINE Both by myself and many other friends:
# LINE But he, his own affections' counsellor,
# LINE Is to himself--I will not say how true--
# LINE But to himself so secret and so close,
# LINE So far from sounding and discovery,
# LINE As is the bud bit with an envious worm,
# LINE Ere he can spread his sweet leaves to the air,
# LINE Or dedicate his beauty to the sun.
# LINE Could we but learn from whence his sorrows grow.
# LINE We would as willingly give cure as know.
# STAGEDIR Enter ROMEO
# SPEECH
#
# SPEAKER BENVOLIO
# LINE See, where he comes: so please you, step aside;
# LINE I'll know his grievance, or be much denied.
# SPEECH
#
# SPEAKER MONTAGUE
# LINE I would thou wert so happy by thy stay,
# LINE To hear true shrift. Come, madam, let's away.
# STAGEDIR Exeunt MONTAGUE and LADY MONTAGUE
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Good-morrow, cousin.
# SPEECH
#
# SPEAKER ROMEO
# LINE Is the day so young?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE But new struck nine.
# SPEECH
#
# SPEAKER ROMEO
# LINE Ay me! sad hours seem long.
# LINE Was that my father that went hence so fast?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE It was. What sadness lengthens Romeo's hours?
# SPEECH
#
# SPEAKER ROMEO
# LINE Not having that, which, having, makes them short.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE In love?
# SPEECH
#
# SPEAKER ROMEO
# LINE Out--
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Of love?
# SPEECH
#
# SPEAKER ROMEO
# LINE Out of her favour, where I am in love.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Alas, that love, so gentle in his view,
# LINE Should be so tyrannous and rough in proof!
# SPEECH
#
# SPEAKER ROMEO
# LINE Alas, that love, whose view is muffled still,
# LINE Should, without eyes, see pathways to his will!
# LINE Where shall we dine? O me! What fray was here?
# LINE Yet tell me not, for I have heard it all.
# LINE Here's much to do with hate, but more with love.
# LINE Why, then, O brawling love! O loving hate!
# LINE O any thing, of nothing first create!
# LINE O heavy lightness! serious vanity!
# LINE Mis-shapen chaos of well-seeming forms!
# LINE Feather of lead, bright smoke, cold fire,
# LINE sick health!
# LINE Still-waking sleep, that is not what it is!
# LINE This love feel I, that feel no love in this.
# LINE Dost thou not laugh?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE No, coz, I rather weep.
# SPEECH
#
# SPEAKER ROMEO
# LINE Good heart, at what?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE At thy good heart's oppression.
# SPEECH
#
# SPEAKER ROMEO
# LINE Why, such is love's transgression.
# LINE Griefs of mine own lie heavy in my breast,
# LINE Which thou wilt propagate, to have it prest
# LINE With more of thine: this love that thou hast shown
# LINE Doth add more grief to too much of mine own.
# LINE Love is a smoke raised with the fume of sighs;
# LINE Being purged, a fire sparkling in lovers' eyes;
# LINE Being vex'd a sea nourish'd with lovers' tears:
# LINE What is it else? a madness most discreet,
# LINE A choking gall and a preserving sweet.
# LINE Farewell, my coz.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Soft! I will go along;
# LINE An if you leave me so, you do me wrong.
# SPEECH
#
# SPEAKER ROMEO
# LINE Tut, I have lost myself; I am not here;
# LINE This is not Romeo, he's some other where.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Tell me in sadness, who is that you love.
# SPEECH
#
# SPEAKER ROMEO
# LINE What, shall I groan and tell thee?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Groan! why, no.
# LINE But sadly tell me who.
# SPEECH
#
# SPEAKER ROMEO
# LINE Bid a sick man in sadness make his will:
# LINE Ah, word ill urged to one that is so ill!
# LINE In sadness, cousin, I do love a woman.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE I aim'd so near, when I supposed you loved.
# SPEECH
#
# SPEAKER ROMEO
# LINE A right good mark-man! And she's fair I love.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE A right fair mark, fair coz, is soonest hit.
# SPEECH
#
# SPEAKER ROMEO
# LINE Well, in that hit you miss: she'll not be hit
# LINE With Cupid's arrow; she hath Dian's wit;
# LINE And, in strong proof of chastity well arm'd,
# LINE From love's weak childish bow she lives unharm'd.
# LINE She will not stay the siege of loving terms,
# LINE Nor bide the encounter of assailing eyes,
# LINE Nor ope her lap to saint-seducing gold:
# LINE O, she is rich in beauty, only poor,
# LINE That when she dies with beauty dies her store.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Then she hath sworn that she will still live chaste?
# SPEECH
#
# SPEAKER ROMEO
# LINE She hath, and in that sparing makes huge waste,
# LINE For beauty starved with her severity
# LINE Cuts beauty off from all posterity.
# LINE She is too fair, too wise, wisely too fair,
# LINE To merit bliss by making me despair:
# LINE She hath forsworn to love, and in that vow
# LINE Do I live dead that live to tell it now.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Be ruled by me, forget to think of her.
# SPEECH
#
# SPEAKER ROMEO
# LINE O, teach me how I should forget to think.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE By giving liberty unto thine eyes;
# LINE Examine other beauties.
# SPEECH
#
# SPEAKER ROMEO
# LINE 'Tis the way
# LINE To call hers exquisite, in question more:
# LINE These happy masks that kiss fair ladies' brows
# LINE Being black put us in mind they hide the fair;
# LINE He that is strucken blind cannot forget
# LINE The precious treasure of his eyesight lost:
# LINE Show me a mistress that is passing fair,
# LINE What doth her beauty serve, but as a note
# LINE Where I may read who pass'd that passing fair?
# LINE Farewell: thou canst not teach me to forget.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE I'll pay that doctrine, or else die in debt.
# STAGEDIR Exeunt
# SCENE None
# TITLE SCENE II.  A street.
# STAGEDIR Enter CAPULET, PARIS, and Servant
# SPEECH
#
# SPEAKER CAPULET
# LINE But Montague is bound as well as I,
# LINE In penalty alike; and 'tis not hard, I think,
# LINE For men so old as we to keep the peace.
# SPEECH
#
# SPEAKER PARIS
# LINE Of honourable reckoning are you both;
# LINE And pity 'tis you lived at odds so long.
# LINE But now, my lord, what say you to my suit?
# SPEECH
#
# SPEAKER CAPULET
# LINE But saying o'er what I have said before:
# LINE My child is yet a stranger in the world;
# LINE She hath not seen the change of fourteen years,
# LINE Let two more summers wither in their pride,
# LINE Ere we may think her ripe to be a bride.
# SPEECH
#
# SPEAKER PARIS
# LINE Younger than she are happy mothers made.
# SPEECH
#
# SPEAKER CAPULET
# LINE And too soon marr'd are those so early made.
# LINE The earth hath swallow'd all my hopes but she,
# LINE She is the hopeful lady of my earth:
# LINE But woo her, gentle Paris, get her heart,
# LINE My will to her consent is but a part;
# LINE An she agree, within her scope of choice
# LINE Lies my consent and fair according voice.
# LINE This night I hold an old accustom'd feast,
# LINE Whereto I have invited many a guest,
# LINE Such as I love; and you, among the store,
# LINE One more, most welcome, makes my number more.
# LINE At my poor house look to behold this night
# LINE Earth-treading stars that make dark heaven light:
# LINE Such comfort as do lusty young men feel
# LINE When well-apparell'd April on the heel
# LINE Of limping winter treads, even such delight
# LINE Among fresh female buds shall you this night
# LINE Inherit at my house; hear all, all see,
# LINE And like her most whose merit most shall be:
# LINE Which on more view, of many mine being one
# LINE May stand in number, though in reckoning none,
# LINE Come, go with me.
# STAGEDIR To Servant, giving a paper
# LINE Go, sirrah, trudge about
# LINE Through fair Verona; find those persons out
# LINE Whose names are written there, and to them say,
# LINE My house and welcome on their pleasure stay.
# STAGEDIR Exeunt CAPULET and PARIS
# SPEECH
#
# SPEAKER Servant
# LINE Find them out whose names are written here! It is
# LINE written, that the shoemaker should meddle with his
# LINE yard, and the tailor with his last, the fisher with
# LINE his pencil, and the painter with his nets; but I am
# LINE sent to find those persons whose names are here
# LINE writ, and can never find what names the writing
# LINE person hath here writ. I must to the learned.--In good time.
# STAGEDIR Enter BENVOLIO and ROMEO
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Tut, man, one fire burns out another's burning,
# LINE One pain is lessen'd by another's anguish;
# LINE Turn giddy, and be holp by backward turning;
# LINE One desperate grief cures with another's languish:
# LINE Take thou some new infection to thy eye,
# LINE And the rank poison of the old will die.
# SPEECH
#
# SPEAKER ROMEO
# LINE Your plaintain-leaf is excellent for that.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE For what, I pray thee?
# SPEECH
#
# SPEAKER ROMEO
# LINE For your broken shin.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Why, Romeo, art thou mad?
# SPEECH
#
# SPEAKER ROMEO
# LINE Not mad, but bound more than a mad-man is;
# LINE Shut up in prison, kept without my food,
# LINE Whipp'd and tormented and--God-den, good fellow.
# SPEECH
#
# SPEAKER Servant
# LINE God gi' god-den. I pray, sir, can you read?
# SPEECH
#
# SPEAKER ROMEO
# LINE Ay, mine own fortune in my misery.
# SPEECH
#
# SPEAKER Servant
# LINE Perhaps you have learned it without book: but, I
# LINE pray, can you read any thing you see?
# SPEECH
#
# SPEAKER ROMEO
# LINE Ay, if I know the letters and the language.
# SPEECH
#
# SPEAKER Servant
# LINE Ye say honestly: rest you merry!
# SPEECH
#
# SPEAKER ROMEO
# LINE Stay, fellow; I can read.
# STAGEDIR Reads
# LINE 'Signior Martino and his wife and daughters;
# LINE County Anselme and his beauteous sisters; the lady
# LINE widow of Vitravio; Signior Placentio and his lovely
# LINE nieces; Mercutio and his brother Valentine; mine
# LINE uncle Capulet, his wife and daughters; my fair niece
# LINE Rosaline; Livia; Signior Valentio and his cousin
# LINE Tybalt, Lucio and the lively Helena.' A fair
# LINE assembly: whither should they come?
# SPEECH
#
# SPEAKER Servant
# LINE Up.
# SPEECH
#
# SPEAKER ROMEO
# LINE Whither?
# SPEECH
#
# SPEAKER Servant
# LINE To supper; to our house.
# SPEECH
#
# SPEAKER ROMEO
# LINE Whose house?
# SPEECH
#
# SPEAKER Servant
# LINE My master's.
# SPEECH
#
# SPEAKER ROMEO
# LINE Indeed, I should have ask'd you that before.
# SPEECH
#
# SPEAKER Servant
# LINE Now I'll tell you without asking: my master is the
# LINE great rich Capulet; and if you be not of the house
# LINE of Montagues, I pray, come and crush a cup of wine.
# LINE Rest you merry!
# STAGEDIR Exit
# SPEECH
#
# SPEAKER BENVOLIO
# LINE At this same ancient feast of Capulet's
# LINE Sups the fair Rosaline whom thou so lovest,
# LINE With all the admired beauties of Verona:
# LINE Go thither; and, with unattainted eye,
# LINE Compare her face with some that I shall show,
# LINE And I will make thee think thy swan a crow.
# SPEECH
#
# SPEAKER ROMEO
# LINE When the devout religion of mine eye
# LINE Maintains such falsehood, then turn tears to fires;
# LINE And these, who often drown'd could never die,
# LINE Transparent heretics, be burnt for liars!
# LINE One fairer than my love! the all-seeing sun
# LINE Ne'er saw her match since first the world begun.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Tut, you saw her fair, none else being by,
# LINE Herself poised with herself in either eye:
# LINE But in that crystal scales let there be weigh'd
# LINE Your lady's love against some other maid
# LINE That I will show you shining at this feast,
# LINE And she shall scant show well that now shows best.
# SPEECH
#
# SPEAKER ROMEO
# LINE I'll go along, no such sight to be shown,
# LINE But to rejoice in splendor of mine own.
# STAGEDIR Exeunt
# SCENE None
# TITLE SCENE III.  A room in Capulet's house.
# STAGEDIR Enter LADY CAPULET and Nurse
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Nurse, where's my daughter? call her forth to me.
# SPEECH
#
# SPEAKER Nurse
# LINE Now, by my maidenhead, at twelve year old,
# LINE I bade her come. What, lamb! what, ladybird!
# LINE God forbid! Where's this girl? What, Juliet!
# STAGEDIR Enter JULIET
# SPEECH
#
# SPEAKER JULIET
# LINE How now! who calls?
# SPEECH
#
# SPEAKER Nurse
# LINE Your mother.
# SPEECH
#
# SPEAKER JULIET
# LINE Madam, I am here.
# LINE What is your will?
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE This is the matter:--Nurse, give leave awhile,
# LINE We must talk in secret:--nurse, come back again;
# LINE I have remember'd me, thou's hear our counsel.
# LINE Thou know'st my daughter's of a pretty age.
# SPEECH
#
# SPEAKER Nurse
# LINE Faith, I can tell her age unto an hour.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE She's not fourteen.
# SPEECH
#
# SPEAKER Nurse
# LINE I'll lay fourteen of my teeth,--
# LINE And yet, to my teeth be it spoken, I have but four--
# LINE She is not fourteen. How long is it now
# LINE To Lammas-tide?
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE A fortnight and odd days.
# SPEECH
#
# SPEAKER Nurse
# LINE Even or odd, of all days in the year,
# LINE Come Lammas-eve at night shall she be fourteen.
# LINE Susan and she--God rest all Christian souls!--
# LINE Were of an age: well, Susan is with God;
# LINE She was too good for me: but, as I said,
# LINE On Lammas-eve at night shall she be fourteen;
# LINE That shall she, marry; I remember it well.
# LINE 'Tis since the earthquake now eleven years;
# LINE And she was wean'd,--I never shall forget it,--
# LINE Of all the days of the year, upon that day:
# LINE For I had then laid wormwood to my dug,
# LINE Sitting in the sun under the dove-house wall;
# LINE My lord and you were then at Mantua:--
# LINE Nay, I do bear a brain:--but, as I said,
# LINE When it did taste the wormwood on the nipple
# LINE Of my dug and felt it bitter, pretty fool,
# LINE To see it tetchy and fall out with the dug!
# LINE Shake quoth the dove-house: 'twas no need, I trow,
# LINE To bid me trudge:
# LINE And since that time it is eleven years;
# LINE For then she could stand alone; nay, by the rood,
# LINE She could have run and waddled all about;
# LINE For even the day before, she broke her brow:
# LINE And then my husband--God be with his soul!
# LINE A' was a merry man--took up the child:
# LINE 'Yea,' quoth he, 'dost thou fall upon thy face?
# LINE Thou wilt fall backward when thou hast more wit;
# LINE Wilt thou not, Jule?' and, by my holidame,
# LINE The pretty wretch left crying and said 'Ay.'
# LINE To see, now, how a jest shall come about!
# LINE I warrant, an I should live a thousand years,
# LINE I never should forget it: 'Wilt thou not, Jule?' quoth he;
# LINE And, pretty fool, it stinted and said 'Ay.'
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Enough of this; I pray thee, hold thy peace.
# SPEECH
#
# SPEAKER Nurse
# LINE Yes, madam: yet I cannot choose but laugh,
# LINE To think it should leave crying and say 'Ay.'
# LINE And yet, I warrant, it had upon its brow
# LINE A bump as big as a young cockerel's stone;
# LINE A parlous knock; and it cried bitterly:
# LINE 'Yea,' quoth my husband,'fall'st upon thy face?
# LINE Thou wilt fall backward when thou comest to age;
# LINE Wilt thou not, Jule?' it stinted and said 'Ay.'
# SPEECH
#
# SPEAKER JULIET
# LINE And stint thou too, I pray thee, nurse, say I.
# SPEECH
#
# SPEAKER Nurse
# LINE Peace, I have done. God mark thee to his grace!
# LINE Thou wast the prettiest babe that e'er I nursed:
# LINE An I might live to see thee married once,
# LINE I have my wish.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Marry, that 'marry' is the very theme
# LINE I came to talk of. Tell me, daughter Juliet,
# LINE How stands your disposition to be married?
# SPEECH
#
# SPEAKER JULIET
# LINE It is an honour that I dream not of.
# SPEECH
#
# SPEAKER Nurse
# LINE An honour! were not I thine only nurse,
# LINE I would say thou hadst suck'd wisdom from thy teat.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Well, think of marriage now; younger than you,
# LINE Here in Verona, ladies of esteem,
# LINE Are made already mothers: by my count,
# LINE I was your mother much upon these years
# LINE That you are now a maid. Thus then in brief:
# LINE The valiant Paris seeks you for his love.
# SPEECH
#
# SPEAKER Nurse
# LINE A man, young lady! lady, such a man
# LINE As all the world--why, he's a man of wax.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Verona's summer hath not such a flower.
# SPEECH
#
# SPEAKER Nurse
# LINE Nay, he's a flower; in faith, a very flower.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE What say you? can you love the gentleman?
# LINE This night you shall behold him at our feast;
# LINE Read o'er the volume of young Paris' face,
# LINE And find delight writ there with beauty's pen;
# LINE Examine every married lineament,
# LINE And see how one another lends content
# LINE And what obscured in this fair volume lies
# LINE Find written in the margent of his eyes.
# LINE This precious book of love, this unbound lover,
# LINE To beautify him, only lacks a cover:
# LINE The fish lives in the sea, and 'tis much pride
# LINE For fair without the fair within to hide:
# LINE That book in many's eyes doth share the glory,
# LINE That in gold clasps locks in the golden story;
# LINE So shall you share all that he doth possess,
# LINE By having him, making yourself no less.
# SPEECH
#
# SPEAKER Nurse
# LINE No less! nay, bigger; women grow by men.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE Speak briefly, can you like of Paris' love?
# SPEECH
#
# SPEAKER JULIET
# LINE I'll look to like, if looking liking move:
# LINE But no more deep will I endart mine eye
# LINE Than your consent gives strength to make it fly.
# STAGEDIR Enter a Servant
# SPEECH
#
# SPEAKER Servant
# LINE Madam, the guests are come, supper served up, you
# LINE called, my young lady asked for, the nurse cursed in
# LINE the pantry, and every thing in extremity. I must
# LINE hence to wait; I beseech you, follow straight.
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE We follow thee.
# STAGEDIR Exit Servant
# LINE Juliet, the county stays.
# SPEECH
#
# SPEAKER Nurse
# LINE Go, girl, seek happy nights to happy days.
# STAGEDIR Exeunt
# SCENE None
# TITLE SCENE IV.  A street.
# STAGEDIR Enter ROMEO, MERCUTIO, BENVOLIO, with five or six
# Maskers, Torch-bearers, and others
# SPEECH
#
# SPEAKER ROMEO
# LINE What, shall this speech be spoke for our excuse?
# LINE Or shall we on without a apology?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE The date is out of such prolixity:
# LINE We'll have no Cupid hoodwink'd with a scarf,
# LINE Bearing a Tartar's painted bow of lath,
# LINE Scaring the ladies like a crow-keeper;
# LINE Nor no without-book prologue, faintly spoke
# LINE After the prompter, for our entrance:
# LINE But let them measure us by what they will;
# LINE We'll measure them a measure, and be gone.
# SPEECH
#
# SPEAKER ROMEO
# LINE Give me a torch: I am not for this ambling;
# LINE Being but heavy, I will bear the light.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE Nay, gentle Romeo, we must have you dance.
# SPEECH
#
# SPEAKER ROMEO
# LINE Not I, believe me: you have dancing shoes
# LINE With nimble soles: I have a soul of lead
# LINE So stakes me to the ground I cannot move.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE You are a lover; borrow Cupid's wings,
# LINE And soar with them above a common bound.
# SPEECH
#
# SPEAKER ROMEO
# LINE I am too sore enpierced with his shaft
# LINE To soar with his light feathers, and so bound,
# LINE I cannot bound a pitch above dull woe:
# LINE Under love's heavy burden do I sink.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE And, to sink in it, should you burden love;
# LINE Too great oppression for a tender thing.
# SPEECH
#
# SPEAKER ROMEO
# LINE Is love a tender thing? it is too rough,
# LINE Too rude, too boisterous, and it pricks like thorn.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE If love be rough with you, be rough with love;
# LINE Prick love for pricking, and you beat love down.
# LINE Give me a case to put my visage in:
# LINE A visor for a visor! what care I
# LINE What curious eye doth quote deformities?
# LINE Here are the beetle brows shall blush for me.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Come, knock and enter; and no sooner in,
# LINE But every man betake him to his legs.
# SPEECH
#
# SPEAKER ROMEO
# LINE A torch for me: let wantons light of heart
# LINE Tickle the senseless rushes with their heels,
# LINE For I am proverb'd with a grandsire phrase;
# LINE I'll be a candle-holder, and look on.
# LINE The game was ne'er so fair, and I am done.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE Tut, dun's the mouse, the constable's own word:
# LINE If thou art dun, we'll draw thee from the mire
# LINE Of this sir-reverence love, wherein thou stick'st
# LINE Up to the ears. Come, we burn daylight, ho!
# SPEECH
#
# SPEAKER ROMEO
# LINE Nay, that's not so.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE I mean, sir, in delay
# LINE We waste our lights in vain, like lamps by day.
# LINE Take our good meaning, for our judgment sits
# LINE Five times in that ere once in our five wits.
# SPEECH
#
# SPEAKER ROMEO
# LINE And we mean well in going to this mask;
# LINE But 'tis no wit to go.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE Why, may one ask?
# SPEECH
#
# SPEAKER ROMEO
# LINE I dream'd a dream to-night.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE And so did I.
# SPEECH
#
# SPEAKER ROMEO
# LINE Well, what was yours?
# SPEECH
#
# SPEAKER MERCUTIO
# LINE That dreamers often lie.
# SPEECH
#
# SPEAKER ROMEO
# LINE In bed asleep, while they do dream things true.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE O, then, I see Queen Mab hath been with you.
# LINE She is the fairies' midwife, and she comes
# LINE In shape no bigger than an agate-stone
# LINE On the fore-finger of an alderman,
# LINE Drawn with a team of little atomies
# LINE Athwart men's noses as they lie asleep;
# LINE Her wagon-spokes made of long spiders' legs,
# LINE The cover of the wings of grasshoppers,
# LINE The traces of the smallest spider's web,
# LINE The collars of the moonshine's watery beams,
# LINE Her whip of cricket's bone, the lash of film,
# LINE Her wagoner a small grey-coated gnat,
# LINE Not so big as a round little worm
# LINE Prick'd from the lazy finger of a maid;
# LINE Her chariot is an empty hazel-nut
# LINE Made by the joiner squirrel or old grub,
# LINE Time out o' mind the fairies' coachmakers.
# LINE And in this state she gallops night by night
# LINE Through lovers' brains, and then they dream of love;
# LINE O'er courtiers' knees, that dream on court'sies straight,
# LINE O'er lawyers' fingers, who straight dream on fees,
# LINE O'er ladies ' lips, who straight on kisses dream,
# LINE Which oft the angry Mab with blisters plagues,
# LINE Because their breaths with sweetmeats tainted are:
# LINE Sometime she gallops o'er a courtier's nose,
# LINE And then dreams he of smelling out a suit;
# LINE And sometime comes she with a tithe-pig's tail
# LINE Tickling a parson's nose as a' lies asleep,
# LINE Then dreams, he of another benefice:
# LINE Sometime she driveth o'er a soldier's neck,
# LINE And then dreams he of cutting foreign throats,
# LINE Of breaches, ambuscadoes, Spanish blades,
# LINE Of healths five-fathom deep; and then anon
# LINE Drums in his ear, at which he starts and wakes,
# LINE And being thus frighted swears a prayer or two
# LINE And sleeps again. This is that very Mab
# LINE That plats the manes of horses in the night,
# LINE And bakes the elflocks in foul sluttish hairs,
# LINE Which once untangled, much misfortune bodes:
# LINE This is the hag, when maids lie on their backs,
# LINE That presses them and learns them first to bear,
# LINE Making them women of good carriage:
# LINE This is she--
# SPEECH
#
# SPEAKER ROMEO
# LINE Peace, peace, Mercutio, peace!
# LINE Thou talk'st of nothing.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE True, I talk of dreams,
# LINE Which are the children of an idle brain,
# LINE Begot of nothing but vain fantasy,
# LINE Which is as thin of substance as the air
# LINE And more inconstant than the wind, who wooes
# LINE Even now the frozen bosom of the north,
# LINE And, being anger'd, puffs away from thence,
# LINE Turning his face to the dew-dropping south.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE This wind, you talk of, blows us from ourselves;
# LINE Supper is done, and we shall come too late.
# SPEECH
#
# SPEAKER ROMEO
# LINE I fear, too early: for my mind misgives
# LINE Some consequence yet hanging in the stars
# LINE Shall bitterly begin his fearful date
# LINE With this night's revels and expire the term
# LINE Of a despised life closed in my breast
# LINE By some vile forfeit of untimely death.
# LINE But He, that hath the steerage of my course,
# LINE Direct my sail! On, lusty gentlemen.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Strike, drum.
# STAGEDIR Exeunt
# SCENE None
# TITLE SCENE V.  A hall in Capulet's house.
# STAGEDIR Musicians waiting. Enter Servingmen with napkins
# SPEECH
#
# SPEAKER First Servant
# LINE Where's Potpan, that he helps not to take away? He
# LINE shift a trencher? he scrape a trencher!
# SPEECH
#
# SPEAKER Second Servant
# LINE When good manners shall lie all in one or two men's
# LINE hands and they unwashed too, 'tis a foul thing.
# SPEECH
#
# SPEAKER First Servant
# LINE Away with the joint-stools, remove the
# LINE court-cupboard, look to the plate. Good thou, save
# LINE me a piece of marchpane; and, as thou lovest me, let
# LINE the porter let in Susan Grindstone and Nell.
# LINE Antony, and Potpan!
# SPEECH
#
# SPEAKER Second Servant
# LINE Ay, boy, ready.
# SPEECH
#
# SPEAKER First Servant
# LINE You are looked for and called for, asked for and
# LINE sought for, in the great chamber.
# SPEECH
#
# SPEAKER Second Servant
# LINE We cannot be here and there too. Cheerly, boys; be
# LINE brisk awhile, and the longer liver take all.
# STAGEDIR Enter CAPULET, with JULIET and others of his house,
# meeting the Guests and Maskers
# SPEECH
#
# SPEAKER CAPULET
# LINE Welcome, gentlemen! ladies that have their toes
# LINE Unplagued with corns will have a bout with you.
# LINE Ah ha, my mistresses! which of you all
# LINE Will now deny to dance? she that makes dainty,
# LINE She, I'll swear, hath corns; am I come near ye now?
# LINE Welcome, gentlemen! I have seen the day
# LINE That I have worn a visor and could tell
# LINE A whispering tale in a fair lady's ear,
# LINE Such as would please: 'tis gone, 'tis gone, 'tis gone:
# LINE You are welcome, gentlemen! come, musicians, play.
# LINE A hall, a hall! give room! and foot it, girls.
# STAGEDIR Music plays, and they dance
# LINE More light, you knaves; and turn the tables up,
# LINE And quench the fire, the room is grown too hot.
# LINE Ah, sirrah, this unlook'd-for sport comes well.
# LINE Nay, sit, nay, sit, good cousin Capulet;
# LINE For you and I are past our dancing days:
# LINE How long is't now since last yourself and I
# LINE Were in a mask?
# SPEECH
#
# SPEAKER Second Capulet
# LINE By'r lady, thirty years.
# SPEECH
#
# SPEAKER CAPULET
# LINE What, man! 'tis not so much, 'tis not so much:
# LINE 'Tis since the nuptials of Lucentio,
# LINE Come pentecost as quickly as it will,
# LINE Some five and twenty years; and then we mask'd.
# SPEECH
#
# SPEAKER Second Capulet
# LINE 'Tis more, 'tis more, his son is elder, sir;
# LINE His son is thirty.
# SPEECH
#
# SPEAKER CAPULET
# LINE Will you tell me that?
# LINE His son was but a ward two years ago.
# SPEECH
#
# SPEAKER ROMEO
# LINE None
# STAGEDIR To a Servingman
# LINE enrich the hand
# LINE Of yonder knight?
# SPEECH
#
# SPEAKER Servant
# LINE I know not, sir.
# SPEECH
#
# SPEAKER ROMEO
# LINE O, she doth teach the torches to burn bright!
# LINE It seems she hangs upon the cheek of night
# LINE Like a rich jewel in an Ethiope's ear;
# LINE Beauty too rich for use, for earth too dear!
# LINE So shows a snowy dove trooping with crows,
# LINE As yonder lady o'er her fellows shows.
# LINE The measure done, I'll watch her place of stand,
# LINE And, touching hers, make blessed my rude hand.
# LINE Did my heart love till now? forswear it, sight!
# LINE For I ne'er saw true beauty till this night.
# SPEECH
#
# SPEAKER TYBALT
# LINE This, by his voice, should be a Montague.
# LINE Fetch me my rapier, boy. What dares the slave
# LINE Come hither, cover'd with an antic face,
# LINE To fleer and scorn at our solemnity?
# LINE Now, by the stock and honour of my kin,
# LINE To strike him dead, I hold it not a sin.
# SPEECH
#
# SPEAKER CAPULET
# LINE Why, how now, kinsman! wherefore storm you so?
# SPEECH
#
# SPEAKER TYBALT
# LINE Uncle, this is a Montague, our foe,
# LINE A villain that is hither come in spite,
# LINE To scorn at our solemnity this night.
# SPEECH
#
# SPEAKER CAPULET
# LINE Young Romeo is it?
# SPEECH
#
# SPEAKER TYBALT
# LINE 'Tis he, that villain Romeo.
# SPEECH
#
# SPEAKER CAPULET
# LINE Content thee, gentle coz, let him alone;
# LINE He bears him like a portly gentleman;
# LINE And, to say truth, Verona brags of him
# LINE To be a virtuous and well-govern'd youth:
# LINE I would not for the wealth of all the town
# LINE Here in my house do him disparagement:
# LINE Therefore be patient, take no note of him:
# LINE It is my will, the which if thou respect,
# LINE Show a fair presence and put off these frowns,
# LINE And ill-beseeming semblance for a feast.
# SPEECH
#
# SPEAKER TYBALT
# LINE It fits, when such a villain is a guest:
# LINE I'll not endure him.
# SPEECH
#
# SPEAKER CAPULET
# LINE He shall be endured:
# LINE What, goodman boy! I say, he shall: go to;
# LINE Am I the master here, or you? go to.
# LINE You'll not endure him! God shall mend my soul!
# LINE You'll make a mutiny among my guests!
# LINE You will set cock-a-hoop! you'll be the man!
# SPEECH
#
# SPEAKER TYBALT
# LINE Why, uncle, 'tis a shame.
# SPEECH
#
# SPEAKER CAPULET
# LINE Go to, go to;
# LINE You are a saucy boy: is't so, indeed?
# LINE This trick may chance to scathe you, I know what:
# LINE You must contrary me! marry, 'tis time.
# LINE Well said, my hearts! You are a princox; go:
# LINE Be quiet, or--More light, more light! For shame!
# LINE I'll make you quiet. What, cheerly, my hearts!
# SPEECH
#
# SPEAKER TYBALT
# LINE Patience perforce with wilful choler meeting
# LINE Makes my flesh tremble in their different greeting.
# LINE I will withdraw: but this intrusion shall
# LINE Now seeming sweet convert to bitter gall.
# STAGEDIR Exit
# SPEECH
#
# SPEAKER ROMEO
# LINE None
# STAGEDIR To JULIET
# LINE This holy shrine, the gentle fine is this:
# LINE My lips, two blushing pilgrims, ready stand
# LINE To smooth that rough touch with a tender kiss.
# SPEECH
#
# SPEAKER JULIET
# LINE Good pilgrim, you do wrong your hand too much,
# LINE Which mannerly devotion shows in this;
# LINE For saints have hands that pilgrims' hands do touch,
# LINE And palm to palm is holy palmers' kiss.
# SPEECH
#
# SPEAKER ROMEO
# LINE Have not saints lips, and holy palmers too?
# SPEECH
#
# SPEAKER JULIET
# LINE Ay, pilgrim, lips that they must use in prayer.
# SPEECH
#
# SPEAKER ROMEO
# LINE O, then, dear saint, let lips do what hands do;
# LINE They pray, grant thou, lest faith turn to despair.
# SPEECH
#
# SPEAKER JULIET
# LINE Saints do not move, though grant for prayers' sake.
# SPEECH
#
# SPEAKER ROMEO
# LINE Then move not, while my prayer's effect I take.
# LINE Thus from my lips, by yours, my sin is purged.
# SPEECH
#
# SPEAKER JULIET
# LINE Then have my lips the sin that they have took.
# SPEECH
#
# SPEAKER ROMEO
# LINE Sin from thy lips? O trespass sweetly urged!
# LINE Give me my sin again.
# SPEECH
#
# SPEAKER JULIET
# LINE You kiss by the book.
# SPEECH
#
# SPEAKER Nurse
# LINE Madam, your mother craves a word with you.
# SPEECH
#
# SPEAKER ROMEO
# LINE What is her mother?
# SPEECH
#
# SPEAKER Nurse
# LINE Marry, bachelor,
# LINE Her mother is the lady of the house,
# LINE And a good lady, and a wise and virtuous
# LINE I nursed her daughter, that you talk'd withal;
# LINE I tell you, he that can lay hold of her
# LINE Shall have the chinks.
# SPEECH
#
# SPEAKER ROMEO
# LINE Is she a Capulet?
# LINE O dear account! my life is my foe's debt.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Away, begone; the sport is at the best.
# SPEECH
#
# SPEAKER ROMEO
# LINE Ay, so I fear; the more is my unrest.
# SPEECH
#
# SPEAKER CAPULET
# LINE Nay, gentlemen, prepare not to be gone;
# LINE We have a trifling foolish banquet towards.
# LINE Is it e'en so? why, then, I thank you all
# LINE I thank you, honest gentlemen; good night.
# LINE More torches here! Come on then, let's to bed.
# LINE Ah, sirrah, by my fay, it waxes late:
# LINE I'll to my rest.
# STAGEDIR Exeunt all but JULIET and Nurse
# SPEECH
#
# SPEAKER JULIET
# LINE Come hither, nurse. What is yond gentleman?
# SPEECH
#
# SPEAKER Nurse
# LINE The son and heir of old Tiberio.
# SPEECH
#
# SPEAKER JULIET
# LINE What's he that now is going out of door?
# SPEECH
#
# SPEAKER Nurse
# LINE Marry, that, I think, be young Petrucio.
# SPEECH
#
# SPEAKER JULIET
# LINE What's he that follows there, that would not dance?
# SPEECH
#
# SPEAKER Nurse
# LINE I know not.
# SPEECH
#
# SPEAKER JULIET
# LINE Go ask his name: if he be married.
# LINE My grave is like to be my wedding bed.
# SPEECH
#
# SPEAKER Nurse
# LINE His name is Romeo, and a Montague;
# LINE The only son of your great enemy.
# SPEECH
#
# SPEAKER JULIET
# LINE My only love sprung from my only hate!
# LINE Too early seen unknown, and known too late!
# LINE Prodigious birth of love it is to me,
# LINE That I must love a loathed enemy.
# SPEECH
#
# SPEAKER Nurse
# LINE What's this? what's this?
# SPEECH
#
# SPEAKER JULIET
# LINE A rhyme I learn'd even now
# LINE Of one I danced withal.
# STAGEDIR One calls within 'Juliet.'
# SPEECH
#
# SPEAKER Nurse
# LINE Anon, anon!
# LINE Come, let's away; the strangers all are gone.
# STAGEDIR Exeunt
# ACT None
# TITLE ACT II
# PROLOGUE None
# TITLE PROLOGUE
# STAGEDIR Enter Chorus
# SPEECH
#
# SPEAKER Chorus
# LINE Now old desire doth in his death-bed lie,
# LINE And young affection gapes to be his heir;
# LINE That fair for which love groan'd for and would die,
# LINE With tender Juliet match'd, is now not fair.
# LINE Now Romeo is beloved and loves again,
# LINE Alike betwitched by the charm of looks,
# LINE But to his foe supposed he must complain,
# LINE And she steal love's sweet bait from fearful hooks:
# LINE Being held a foe, he may not have access
# LINE To breathe such vows as lovers use to swear;
# LINE And she as much in love, her means much less
# LINE To meet her new-beloved any where:
# LINE But passion lends them power, time means, to meet
# LINE Tempering extremities with extreme sweet.
# STAGEDIR Exit
# SCENE None
# TITLE SCENE I.  A lane by the wall of Capulet's orchard.
# STAGEDIR Enter ROMEO
# SPEECH
#
# SPEAKER ROMEO
# LINE Can I go forward when my heart is here?
# LINE Turn back, dull earth, and find thy centre out.
# STAGEDIR He climbs the wall, and leaps down within it
# STAGEDIR Enter BENVOLIO and MERCUTIO
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Romeo! my cousin Romeo!
# SPEECH
#
# SPEAKER MERCUTIO
# LINE He is wise;
# LINE And, on my lie, hath stol'n him home to bed.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE He ran this way, and leap'd this orchard wall:
# LINE Call, good Mercutio.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE Nay, I'll conjure too.
# LINE Romeo! humours! madman! passion! lover!
# LINE Appear thou in the likeness of a sigh:
# LINE Speak but one rhyme, and I am satisfied;
# LINE Cry but 'Ay me!' pronounce but 'love' and 'dove;'
# LINE Speak to my gossip Venus one fair word,
# LINE One nick-name for her purblind son and heir,
# LINE Young Adam Cupid, he that shot so trim,
# LINE When King Cophetua loved the beggar-maid!
# LINE He heareth not, he stirreth not, he moveth not;
# LINE The ape is dead, and I must conjure him.
# LINE I conjure thee by Rosaline's bright eyes,
# LINE By her high forehead and her scarlet lip,
# LINE By her fine foot, straight leg and quivering thigh
# LINE And the demesnes that there adjacent lie,
# LINE That in thy likeness thou appear to us!
# SPEECH
#
# SPEAKER BENVOLIO
# LINE And if he hear thee, thou wilt anger him.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE This cannot anger him: 'twould anger him
# LINE To raise a spirit in his mistress' circle
# LINE Of some strange nature, letting it there stand
# LINE Till she had laid it and conjured it down;
# LINE That were some spite: my invocation
# LINE Is fair and honest, and in his mistress' name
# LINE I conjure only but to raise up him.
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Come, he hath hid himself among these trees,
# LINE To be consorted with the humorous night:
# LINE Blind is his love and best befits the dark.
# SPEECH
#
# SPEAKER MERCUTIO
# LINE If love be blind, love cannot hit the mark.
# LINE Now will he sit under a medlar tree,
# LINE And wish his mistress were that kind of fruit
# LINE As maids call medlars, when they laugh alone.
# LINE Romeo, that she were, O, that she were
# LINE An open et caetera, thou a poperin pear!
# LINE Romeo, good night: I'll to my truckle-bed;
# LINE This field-bed is too cold for me to sleep:
# LINE Come, shall we go?
# SPEECH
#
# SPEAKER BENVOLIO
# LINE Go, then; for 'tis in vain
# LINE To seek him here that means not to be found.
# STAGEDIR Exeunt
# SCENE None
# TITLE SCENE II.  Capulet's orchard.
# STAGEDIR Enter ROMEO
# SPEECH
#
# SPEAKER ROMEO
# LINE He jests at scars that never felt a wound.
# STAGEDIR JULIET appears above at a window
# LINE But, soft! what light through yonder window breaks?
# LINE It is the east, and Juliet is the sun.
# LINE Arise, fair sun, and kill the envious moon,
# LINE Who is already sick and pale with grief,
# LINE That thou her maid art far more fair than she:
# LINE Be not her maid, since she is envious;
# LINE Her vestal livery is but sick and green
# LINE And none but fools do wear it; cast it off.
# LINE It is my lady, O, it is my love!
# LINE O, that she knew she were!
# LINE She speaks yet she says nothing: what of that?
# LINE Her eye discourses; I will answer it.
# LINE I am too bold, 'tis not to me she speaks:
# LINE Two of the fairest stars in all the heaven,
# LINE Having some business, do entreat her eyes
# LINE To twinkle in their spheres till they return.
# LINE What if her eyes were there, they in her head?
# LINE The brightness of her cheek would shame those stars,
# LINE As daylight doth a lamp; her eyes in heaven
# LINE Would through the airy region stream so bright
# LINE That birds would sing and think it were not night.
# LINE See, how she leans her cheek upon her hand!
# LINE O, that I were a glove upon that hand,
# LINE That I might touch that cheek!
# SPEECH
#
# SPEAKER JULIET
# LINE Ay me!
# SPEECH
#
# SPEAKER ROMEO
# LINE She speaks:
# LINE O, speak again, bright angel! for thou art
# LINE As glorious to this night, being o'er my head
# LINE As is a winged messenger of heaven
# LINE Unto the white-upturned wondering eyes
# LINE Of mortals that fall back to gaze on him
# LINE When he bestrides the lazy-pacing clouds
# LINE And sails upon the bosom of the air.
# SPEECH
#
# SPEAKER JULIET
# LINE O Romeo, Romeo! wherefore art thou Romeo?
# LINE Deny thy father and refuse thy name;
# LINE Or, if thou wilt not, be but sworn my love,
# LINE And I'll no longer be a Capulet.
# SPEECH
#
# SPEAKER ROMEO
# LINE None
# STAGEDIR Aside
# SPEECH
#
# SPEAKER JULIET
# LINE 'Tis but thy name that is my enemy;
# LINE Thou art thyself, though not a Montague.
# LINE What's Montague? it is nor hand, nor foot,
# LINE Nor arm, nor face, nor any other part
# LINE Belonging to a man. O, be some other name!
# LINE What's in a name? that which we call a rose
# LINE By any other name would smell as sweet;
# ...
# LINE Give me the light: upon thy life, I charge thee,
# LINE Whate'er thou hear'st or seest, stand all aloof,
# LINE And do not interrupt me in my course.
# LINE Why I descend into this bed of death,
# LINE Is partly to behold my lady's face;
# LINE But chiefly to take thence from her dead finger
# LINE A precious ring, a ring that I must use
# LINE In dear employment: therefore hence, be gone:
# LINE But if thou, jealous, dost return to pry
# LINE In what I further shall intend to do,
# LINE By heaven, I will tear thee joint by joint
# LINE And strew this hungry churchyard with thy limbs:
# LINE The time and my intents are savage-wild,
# LINE More fierce and more inexorable far
# LINE Than empty tigers or the roaring sea.
# SPEECH
#
# SPEAKER BALTHASAR
# LINE I will be gone, sir, and not trouble you.
# SPEECH
#
# SPEAKER ROMEO
# LINE So shalt thou show me friendship. Take thou that:
# LINE Live, and be prosperous: and farewell, good fellow.
# SPEECH
#
# SPEAKER BALTHASAR
# LINE None
# STAGEDIR Aside
# LINE His looks I fear, and his intents I doubt.
# STAGEDIR Retires
# SPEECH
#
# SPEAKER ROMEO
# LINE Thou detestable maw, thou womb of death,
# LINE Gorged with the dearest morsel of the earth,
# LINE Thus I enforce thy rotten jaws to open,
# LINE And, in despite, I'll cram thee with more food!
# STAGEDIR Opens the tomb
# SPEECH
#
# SPEAKER PARIS
# LINE This is that banish'd haughty Montague,
# LINE That murder'd my love's cousin, with which grief,
# LINE It is supposed, the fair creature died;
# LINE And here is come to do some villanous shame
# LINE To the dead bodies: I will apprehend him.
# STAGEDIR Comes forward
# LINE Stop thy unhallow'd toil, vile Montague!
# LINE Can vengeance be pursued further than death?
# LINE Condemned villain, I do apprehend thee:
# LINE Obey, and go with me; for thou must die.
# SPEECH
#
# SPEAKER ROMEO
# LINE I must indeed; and therefore came I hither.
# LINE Good gentle youth, tempt not a desperate man;
# LINE Fly hence, and leave me: think upon these gone;
# LINE Let them affright thee. I beseech thee, youth,
# LINE Put not another sin upon my head,
# LINE By urging me to fury: O, be gone!
# LINE By heaven, I love thee better than myself;
# LINE For I come hither arm'd against myself:
# LINE Stay not, be gone; live, and hereafter say,
# LINE A madman's mercy bade thee run away.
# SPEECH
#
# SPEAKER PARIS
# LINE I do defy thy conjurations,
# LINE And apprehend thee for a felon here.
# SPEECH
#
# SPEAKER ROMEO
# LINE Wilt thou provoke me? then have at thee, boy!
# STAGEDIR They fight
# SPEECH
#
# SPEAKER PAGE
# LINE O Lord, they fight! I will go call the watch.
# STAGEDIR Exit
# SPEECH
#
# SPEAKER PARIS
# LINE O, I am slain!
# STAGEDIR Falls
# LINE If thou be merciful,
# LINE Open the tomb, lay me with Juliet.
# STAGEDIR Dies
# SPEECH
#
# SPEAKER ROMEO
# LINE In faith, I will. Let me peruse this face.
# LINE Mercutio's kinsman, noble County Paris!
# LINE What said my man, when my betossed soul
# LINE Did not attend him as we rode? I think
# LINE He told me Paris should have married Juliet:
# LINE Said he not so? or did I dream it so?
# LINE Or am I mad, hearing him talk of Juliet,
# LINE To think it was so? O, give me thy hand,
# LINE One writ with me in sour misfortune's book!
# LINE I'll bury thee in a triumphant grave;
# LINE A grave? O no! a lantern, slaughter'd youth,
# LINE For here lies Juliet, and her beauty makes
# LINE This vault a feasting presence full of light.
# LINE Death, lie thou there, by a dead man interr'd.
# STAGEDIR Laying PARIS in the tomb
# LINE How oft when men are at the point of death
# LINE Have they been merry! which their keepers call
# LINE A lightning before death: O, how may I
# LINE Call this a lightning? O my love! my wife!
# LINE Death, that hath suck'd the honey of thy breath,
# LINE Hath had no power yet upon thy beauty:
# LINE Thou art not conquer'd; beauty's ensign yet
# LINE Is crimson in thy lips and in thy cheeks,
# LINE And death's pale flag is not advanced there.
# LINE Tybalt, liest thou there in thy bloody sheet?
# LINE O, what more favour can I do to thee,
# LINE Than with that hand that cut thy youth in twain
# LINE To sunder his that was thine enemy?
# LINE Forgive me, cousin! Ah, dear Juliet,
# LINE Why art thou yet so fair? shall I believe
# LINE That unsubstantial death is amorous,
# LINE And that the lean abhorred monster keeps
# LINE Thee here in dark to be his paramour?
# LINE For fear of that, I still will stay with thee;
# LINE And never from this palace of dim night
# LINE Depart again: here, here will I remain
# LINE With worms that are thy chamber-maids; O, here
# LINE Will I set up my everlasting rest,
# LINE And shake the yoke of inauspicious stars
# LINE From this world-wearied flesh. Eyes, look your last!
# LINE Arms, take your last embrace! and, lips, O you
# LINE The doors of breath, seal with a righteous kiss
# LINE A dateless bargain to engrossing death!
# LINE Come, bitter conduct, come, unsavoury guide!
# LINE Thou desperate pilot, now at once run on
# LINE The dashing rocks thy sea-sick weary bark!
# LINE Here's to my love!
# STAGEDIR Drinks
# LINE O true apothecary!
# LINE Thy drugs are quick. Thus with a kiss I die.
# STAGEDIR Dies
# STAGEDIR Enter, at the other end of the churchyard, FRIAR
# LAURENCE, with a lantern, crow, and spade
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Saint Francis be my speed! how oft to-night
# LINE Have my old feet stumbled at graves! Who's there?
# SPEECH
#
# SPEAKER BALTHASAR
# LINE Here's one, a friend, and one that knows you well.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Bliss be upon you! Tell me, good my friend,
# LINE What torch is yond, that vainly lends his light
# LINE To grubs and eyeless skulls? as I discern,
# LINE It burneth in the Capel's monument.
# SPEECH
#
# SPEAKER BALTHASAR
# LINE It doth so, holy sir; and there's my master,
# LINE One that you love.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Who is it?
# SPEECH
#
# SPEAKER BALTHASAR
# LINE Romeo.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE How long hath he been there?
# SPEECH
#
# SPEAKER BALTHASAR
# LINE Full half an hour.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Go with me to the vault.
# SPEECH
#
# SPEAKER BALTHASAR
# LINE I dare not, sir
# LINE My master knows not but I am gone hence;
# LINE And fearfully did menace me with death,
# LINE If I did stay to look on his intents.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Stay, then; I'll go alone. Fear comes upon me:
# LINE O, much I fear some ill unlucky thing.
# SPEECH
#
# SPEAKER BALTHASAR
# LINE As I did sleep under this yew-tree here,
# LINE I dreamt my master and another fought,
# LINE And that my master slew him.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE Romeo!
# STAGEDIR Advances
# LINE Alack, alack, what blood is this, which stains
# LINE The stony entrance of this sepulchre?
# LINE What mean these masterless and gory swords
# LINE To lie discolour'd by this place of peace?
# STAGEDIR Enters the tomb
# LINE Romeo! O, pale! Who else? what, Paris too?
# LINE And steep'd in blood? Ah, what an unkind hour
# LINE Is guilty of this lamentable chance!
# LINE The lady stirs.
# STAGEDIR JULIET wakes
# SPEECH
#
# SPEAKER JULIET
# LINE O comfortable friar! where is my lord?
# LINE I do remember well where I should be,
# LINE And there I am. Where is my Romeo?
# STAGEDIR Noise within
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE I hear some noise. Lady, come from that nest
# LINE Of death, contagion, and unnatural sleep:
# LINE A greater power than we can contradict
# LINE Hath thwarted our intents. Come, come away.
# LINE Thy husband in thy bosom there lies dead;
# LINE And Paris too. Come, I'll dispose of thee
# LINE Among a sisterhood of holy nuns:
# LINE Stay not to question, for the watch is coming;
# LINE Come, go, good Juliet,
# STAGEDIR Noise again
# LINE I dare no longer stay.
# SPEECH
#
# SPEAKER JULIET
# LINE Go, get thee hence, for I will not away.
# STAGEDIR Exit FRIAR LAURENCE
# LINE What's here? a cup, closed in my true love's hand?
# LINE Poison, I see, hath been his timeless end:
# LINE O churl! drunk all, and left no friendly drop
# LINE To help me after? I will kiss thy lips;
# LINE Haply some poison yet doth hang on them,
# LINE To make die with a restorative.
# STAGEDIR Kisses him
# LINE Thy lips are warm.
# SPEECH
#
# SPEAKER First Watchman
# LINE None
# STAGEDIR Within
# SPEECH
#
# SPEAKER JULIET
# LINE Yea, noise? then I'll be brief. O happy dagger!
# STAGEDIR Snatching ROMEO's dagger
# LINE This is thy sheath;
# STAGEDIR Stabs herself
# LINE there rust, and let me die.
# STAGEDIR Falls on ROMEO's body, and dies
# STAGEDIR Enter Watch, with the Page of PARIS
# SPEECH
#
# SPEAKER PAGE
# LINE This is the place; there, where the torch doth burn.
# SPEECH
#
# SPEAKER First Watchman
# LINE The ground is bloody; search about the churchyard:
# LINE Go, some of you, whoe'er you find attach.
# LINE Pitiful sight! here lies the county slain,
# LINE And Juliet bleeding, warm, and newly dead,
# LINE Who here hath lain these two days buried.
# LINE Go, tell the prince: run to the Capulets:
# LINE Raise up the Montagues: some others search:
# LINE We see the ground whereon these woes do lie;
# LINE But the true ground of all these piteous woes
# LINE We cannot without circumstance descry.
# STAGEDIR Re-enter some of the Watch, with BALTHASAR
# SPEECH
#
# SPEAKER Second Watchman
# LINE Here's Romeo's man; we found him in the churchyard.
# SPEECH
#
# SPEAKER First Watchman
# LINE Hold him in safety, till the prince come hither.
# STAGEDIR Re-enter others of the Watch, with FRIAR LAURENCE
# SPEECH
#
# SPEAKER Third Watchman
# LINE Here is a friar, that trembles, sighs and weeps:
# LINE We took this mattock and this spade from him,
# LINE As he was coming from this churchyard side.
# SPEECH
#
# SPEAKER First Watchman
# LINE A great suspicion: stay the friar too.
# STAGEDIR Enter the PRINCE and Attendants
# SPEECH
#
# SPEAKER PRINCE
# LINE What misadventure is so early up,
# LINE That calls our person from our morning's rest?
# STAGEDIR Enter CAPULET, LADY CAPULET, and others
# SPEECH
#
# SPEAKER CAPULET
# LINE What should it be, that they so shriek abroad?
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE The people in the street cry Romeo,
# LINE Some Juliet, and some Paris; and all run,
# LINE With open outcry toward our monument.
# SPEECH
#
# SPEAKER PRINCE
# LINE What fear is this which startles in our ears?
# SPEECH
#
# SPEAKER First Watchman
# LINE Sovereign, here lies the County Paris slain;
# LINE And Romeo dead; and Juliet, dead before,
# LINE Warm and new kill'd.
# SPEECH
#
# SPEAKER PRINCE
# LINE Search, seek, and know how this foul murder comes.
# SPEECH
#
# SPEAKER First Watchman
# LINE Here is a friar, and slaughter'd Romeo's man;
# LINE With instruments upon them, fit to open
# LINE These dead men's tombs.
# SPEECH
#
# SPEAKER CAPULET
# LINE O heavens! O wife, look how our daughter bleeds!
# LINE This dagger hath mista'en--for, lo, his house
# LINE Is empty on the back of Montague,--
# LINE And it mis-sheathed in my daughter's bosom!
# SPEECH
#
# SPEAKER LADY CAPULET
# LINE O me! this sight of death is as a bell,
# LINE That warns my old age to a sepulchre.
# STAGEDIR Enter MONTAGUE and others
# SPEECH
#
# SPEAKER PRINCE
# LINE Come, Montague; for thou art early up,
# LINE To see thy son and heir more early down.
# SPEECH
#
# SPEAKER MONTAGUE
# LINE Alas, my liege, my wife is dead to-night;
# LINE Grief of my son's exile hath stopp'd her breath:
# LINE What further woe conspires against mine age?
# SPEECH
#
# SPEAKER PRINCE
# LINE Look, and thou shalt see.
# SPEECH
#
# SPEAKER MONTAGUE
# LINE O thou untaught! what manners is in this?
# LINE To press before thy father to a grave?
# SPEECH
#
# SPEAKER PRINCE
# LINE Seal up the mouth of outrage for a while,
# LINE Till we can clear these ambiguities,
# LINE And know their spring, their head, their
# LINE true descent;
# LINE And then will I be general of your woes,
# LINE And lead you even to death: meantime forbear,
# LINE And let mischance be slave to patience.
# LINE Bring forth the parties of suspicion.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE I am the greatest, able to do least,
# LINE Yet most suspected, as the time and place
# LINE Doth make against me of this direful murder;
# LINE And here I stand, both to impeach and purge
# LINE Myself condemned and myself excused.
# SPEECH
#
# SPEAKER PRINCE
# LINE Then say at once what thou dost know in this.
# SPEECH
#
# SPEAKER FRIAR LAURENCE
# LINE I will be brief, for my short date of breath
# LINE Is not so long as is a tedious tale.
# LINE Romeo, there dead, was husband to that Juliet;
# LINE And she, there dead, that Romeo's faithful wife:
# LINE I married them; and their stol'n marriage-day
# LINE Was Tybalt's dooms-day, whose untimely death
# LINE Banish'd the new-made bridegroom from the city,
# LINE For whom, and not for Tybalt, Juliet pined.
# LINE You, to remove that siege of grief from her,
# LINE Betroth'd and would have married her perforce
# LINE To County Paris: then comes she to me,
# LINE And, with wild looks, bid me devise some mean
# LINE To rid her from this second marriage,
# LINE Or in my cell there would she kill herself.
# LINE Then gave I her, so tutor'd by my art,
# LINE A sleeping potion; which so took effect
# LINE As I intended, for it wrought on her
# LINE The form of death: meantime I writ to Romeo,
# LINE That he should hither come as this dire night,
# LINE To help to take her from her borrow'd grave,
# LINE Being the time the potion's force should cease.
# LINE But he which bore my letter, Friar John,
# LINE Was stay'd by accident, and yesternight
# LINE Return'd my letter back. Then all alone
# LINE At the prefixed hour of her waking,
# LINE Came I to take her from her kindred's vault;
# LINE Meaning to keep her closely at my cell,
# LINE Till I conveniently could send to Romeo:
# LINE But when I came, some minute ere the time
# LINE Of her awaking, here untimely lay
# LINE The noble Paris and true Romeo dead.
# LINE She wakes; and I entreated her come forth,
# LINE And bear this work of heaven with patience:
# LINE But then a noise did scare me from the tomb;
# LINE And she, too desperate, would not go with me,
# LINE But, as it seems, did violence on herself.
# LINE All this I know; and to the marriage
# LINE Her nurse is privy: and, if aught in this
# LINE Miscarried by my fault, let my old life
# LINE Be sacrificed, some hour before his time,
# LINE Unto the rigour of severest law.
# SPEECH
#
# SPEAKER PRINCE
# LINE We still have known thee for a holy man.
# LINE Where's Romeo's man? what can he say in this?
# SPEECH
#
# SPEAKER BALTHASAR
# LINE I brought my master news of Juliet's death;
# LINE And then in post he came from Mantua
# LINE To this same place, to this same monument.
# LINE This letter he early bid me give his father,
# LINE And threatened me with death, going in the vault,
# LINE I departed not and left him there.
# SPEECH
#
# SPEAKER PRINCE
# LINE Give me the letter; I will look on it.
# LINE Where is the county's page, that raised the watch?
# LINE Sirrah, what made your master in this place?
# SPEECH
#
# SPEAKER PAGE
# LINE He came with flowers to strew his lady's grave;
# LINE And bid me stand aloof, and so I did:
# LINE Anon comes one with light to ope the tomb;
# LINE And by and by my master drew on him;
# LINE And then I ran away to call the watch.
# SPEECH
#
# SPEAKER PRINCE
# LINE This letter doth make good the friar's words,
# LINE Their course of love, the tidings of her death:
# LINE And here he writes that he did buy a poison
# LINE Of a poor 'pothecary, and therewithal
# LINE Came to this vault to die, and lie with Juliet.
# LINE Where be these enemies? Capulet! Montague!
# LINE See, what a scourge is laid upon your hate,
# LINE That heaven finds means to kill your joys with love.
# LINE And I for winking at your discords too
# LINE Have lost a brace of kinsmen: all are punish'd.
# SPEECH
#
# SPEAKER CAPULET
# LINE O brother Montague, give me thy hand:
# LINE This is my daughter's jointure, for no more
# LINE Can I demand.
# SPEECH
#
# SPEAKER MONTAGUE
# LINE But I can give thee more:
# LINE For I will raise her statue in pure gold;
# LINE That while Verona by that name is known,
# LINE There shall no figure at such rate be set
# LINE As that of true and faithful Juliet.
# SPEECH
#
# SPEAKER CAPULET
# LINE As rich shall Romeo's by his lady's lie;
# LINE Poor sacrifices of our enmity!
# SPEECH
#
# SPEAKER PRINCE
# LINE A glooming peace this morning with it brings;
# LINE The sun, for sorrow, will not show his head:
# LINE Go hence, to have more talk of these sad things;
# LINE Some shall be pardon'd, and some punished:
# LINE For never was a story of more woe
# LINE Than this of Juliet and her Romeo.
# STAGEDIR Exeunt

# %%
def print_header(header_title: str):
    print("="*50)
    print(f"{header_title}")
    print("="*50)

# %%
import eda_utils as eda_utils

print_header("Character Networks")
eda_utils.build_networks_for_all(works)
print_header("Character Speeches")
eda_utils.extract_all_speeches_and_lines(works)
print_header("Story Stats")
eda_utils.create_story_stats(works)
# Out:
# ==================================================
# Character Networks
# ==================================================
# Saved cleaned network for A Midsummer Night's Dream: ../csv/a_midsummer_night's_dream_network.csv
# Saved cleaned network for The Tragedy of Hamlet, Prince of Denmark: ../csv/the_tragedy_of_hamlet,_prince_of_denmark_network.csv
# Saved cleaned network for The Tragedy of Macbeth: ../csv/the_tragedy_of_macbeth_network.csv
# Saved cleaned network for The Tragedy of Romeo and Juliet: ../csv/the_tragedy_of_romeo_and_juliet_network.csv
# Saved cleaned network for The Tragedy of Antony and Cleopatra: ../csv/the_tragedy_of_antony_and_cleopatra_network.csv
# Saved cleaned network for The Tragedy of Julius Caesar: ../csv/the_tragedy_of_julius_caesar_network.csv
# Saved cleaned network for The Merchant of Venice: ../csv/the_merchant_of_venice_network.csv
# Saved cleaned network for The Tragedy of Othello, the Moor of Venice: ../csv/the_tragedy_of_othello,_the_moor_of_venice_network.csv
# ==================================================
# Character Speeches
# ==================================================
# Extracting speeches and lines for A Midsummer Night's Dream...
# Saved ../csv/a_midsummer_nights_dream_speeches.csv (498 speeches)
# Saved ../csv/a_midsummer_nights_dream_lines.csv (2149 lines)
# Extracting speeches and lines for The Tragedy of Hamlet, Prince of Denmark...
# Saved ../csv/the_tragedy_of_hamlet,_prince_of_denmark_speeches.csv (1126 speeches)
# Saved ../csv/the_tragedy_of_hamlet,_prince_of_denmark_lines.csv (3988 lines)
# Extracting speeches and lines for The Tragedy of Macbeth...
# Saved ../csv/the_tragedy_of_macbeth_speeches.csv (648 speeches)
# Saved ../csv/the_tragedy_of_macbeth_lines.csv (2374 lines)
# Extracting speeches and lines for The Tragedy of Romeo and Juliet...
# Saved ../csv/the_tragedy_of_romeo_and_juliet_speeches.csv (834 speeches)
# Saved ../csv/the_tragedy_of_romeo_and_juliet_lines.csv (3052 lines)
# Extracting speeches and lines for The Tragedy of Antony and Cleopatra...
# Saved ../csv/the_tragedy_of_antony_and_cleopatra_speeches.csv (1172 speeches)
# Saved ../csv/the_tragedy_of_antony_and_cleopatra_lines.csv (3538 lines)
# Extracting speeches and lines for The Tragedy of Julius Caesar...
# Saved ../csv/the_tragedy_of_julius_caesar_speeches.csv (792 speeches)
# Saved ../csv/the_tragedy_of_julius_caesar_lines.csv (2590 lines)
# Extracting speeches and lines for The Merchant of Venice...
# Saved ../csv/the_merchant_of_venice_speeches.csv (636 speeches)
# Saved ../csv/the_merchant_of_venice_lines.csv (2655 lines)
# Extracting speeches and lines for The Tragedy of Othello, the Moor of Venice...
# Saved ../csv/the_tragedy_of_othello,_the_moor_of_venice_speeches.csv (1173 speeches)
# Saved ../csv/the_tragedy_of_othello,_the_moor_of_venice_lines.csv (3535 lines)
# ==================================================
# Story Stats
# ==================================================
# Saved play summary: ../csv/a_midsummer_nights_dream_story_stats.csv
# A Midsummer Night's Dream - Act 1: 2 scenes
# A Midsummer Night's Dream - Act 2: 2 scenes
# A Midsummer Night's Dream - Act 3: 2 scenes
# A Midsummer Night's Dream - Act 4: 2 scenes
# A Midsummer Night's Dream - Act 5: 1 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       2        90             356                  7.0
#    2       2        62             427                  7.0
#    3       2       179             678                  9.5
#    4       2        64             263                  9.5
#    5       1       103             425                 15.0
# Saved detailed layout: ../csv/a_midsummer_nights_dream_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_hamlet,_prince_of_denmark_story_stats.csv
# The Tragedy of Hamlet, Prince of Denmark - Act 1: 5 scenes
# The Tragedy of Hamlet, Prince of Denmark - Act 2: 2 scenes
# The Tragedy of Hamlet, Prince of Denmark - Act 3: 4 scenes
# The Tragedy of Hamlet, Prince of Denmark - Act 4: 7 scenes
# The Tragedy of Hamlet, Prince of Denmark - Act 5: 2 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       5       242             904             5.000000
#    2       2       198             740             5.500000
#    3       4       244             920             7.500000
#    4       7       177             688             3.714286
#    5       2       255             726             9.500000
# Saved detailed layout: ../csv/the_tragedy_of_hamlet,_prince_of_denmark_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_macbeth_story_stats.csv
# The Tragedy of Macbeth - Act 1: 7 scenes
# The Tragedy of Macbeth - Act 2: 4 scenes
# The Tragedy of Macbeth - Act 3: 6 scenes
# The Tragedy of Macbeth - Act 4: 3 scenes
# The Tragedy of Macbeth - Act 5: 8 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       7       121             529             4.142857
#    2       4       118             391             4.250000
#    3       6       127             508             4.000000
#    4       3       159             548             6.333333
#    5       8       122             397             4.125000
# Saved detailed layout: ../csv/the_tragedy_of_macbeth_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_romeo_and_juliet_story_stats.csv
# The Tragedy of Romeo and Juliet - Act 1: 5 scenes
# The Tragedy of Romeo and Juliet - Act 2: 6 scenes
# The Tragedy of Romeo and Juliet - Act 3: 5 scenes
# The Tragedy of Romeo and Juliet - Act 4: 5 scenes
# The Tragedy of Romeo and Juliet - Act 5: 3 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       5       235             722             6.800000
#    2       6       201             668             2.833333
#    3       5       196             818             4.200000
#    4       5       115             406             5.200000
#    5       3        87             438             6.000000
# Saved detailed layout: ../csv/the_tragedy_of_romeo_and_juliet_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_antony_and_cleopatra_story_stats.csv
# The Tragedy of Antony and Cleopatra - Act 1: 5 scenes
# The Tragedy of Antony and Cleopatra - Act 2: 7 scenes
# The Tragedy of Antony and Cleopatra - Act 3: 13 scenes
# The Tragedy of Antony and Cleopatra - Act 4: 15 scenes
# The Tragedy of Antony and Cleopatra - Act 5: 2 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       5       196             582             5.200000
#    2       7       319             867             5.142857
#    3      13       290             874             3.769231
#    4      15       208             690             3.866667
#    5       2       154             520            10.000000
# Saved detailed layout: ../csv/the_tragedy_of_antony_and_cleopatra_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_julius_caesar_story_stats.csv
# The Tragedy of Julius Caesar - Act 1: 3 scenes
# The Tragedy of Julius Caesar - Act 2: 4 scenes
# The Tragedy of Julius Caesar - Act 3: 3 scenes
# The Tragedy of Julius Caesar - Act 4: 3 scenes
# The Tragedy of Julius Caesar - Act 5: 5 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       3       142             574             5.000000
#    2       4       137             551             5.500000
#    3       3       205             632             9.666667
#    4       3       183             455             6.333333
#    5       5       122             375             5.600000
# Saved detailed layout: ../csv/the_tragedy_of_julius_caesar_layout.csv
#
# Saved play summary: ../csv/the_merchant_of_venice_story_stats.csv
# The Merchant of Venice - Act 1: 3 scenes
# The Merchant of Venice - Act 2: 9 scenes
# The Merchant of Venice - Act 3: 5 scenes
# The Merchant of Venice - Act 4: 2 scenes
# The Merchant of Venice - Act 5: 1 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       3       107             498             4.000000
#    2       9       161             676             3.333333
#    3       5       136             664             4.800000
#    4       2       142             493             6.000000
#    5       1        90             324             9.000000
# Saved detailed layout: ../csv/the_merchant_of_venice_layout.csv
#
# Saved play summary: ../csv/the_tragedy_of_othello,_the_moor_of_venice_story_stats.csv
# The Tragedy of Othello, the Moor of Venice - Act 1: 3 scenes
# The Tragedy of Othello, the Moor of Venice - Act 2: 3 scenes
# The Tragedy of Othello, the Moor of Venice - Act 3: 4 scenes
# The Tragedy of Othello, the Moor of Venice - Act 4: 3 scenes
# The Tragedy of Othello, the Moor of Venice - Act 5: 2 scenes
#
# Act-Level Summary:
#  Act  Scenes  Speeches  Dialogue Lines  Avg Unique Speakers
#    1       3       161             735             7.000000
#    2       3       185             731             6.666667
#    3       4       283             823             5.000000
#    4       3       289             685             5.000000
#    5       2       253             559             8.500000
# Saved detailed layout: ../csv/the_tragedy_of_othello,_the_moor_of_venice_layout.csv
#
# Saved combined story summary for all plays: ../csv/all_plays_story_stats.csv
#                                          Play  Acts  Scenes  Speeches  \
# 0                   A Midsummer Night's Dream     5       9       498
# 1    The Tragedy of Hamlet, Prince of Denmark     5      20      1116
# 2                      The Tragedy of Macbeth     5      28       647
# 3             The Tragedy of Romeo and Juliet     5      24       836
# 4         The Tragedy of Antony and Cleopatra     5      42      1167
# 5                The Tragedy of Julius Caesar     5      18       789
# 6                      The Merchant of Venice     5      20       636
# 7  The Tragedy of Othello, the Moor of Venice     5      15      1171
#
#    Dialogue Lines  Main Characters  Side Characters  Total Characters  \
# 0            2149               21                2                23
# 1            3978               21                5                26
# 2            2373               21                5                26
# 3            3080               18                7                25
# 4            3533               33                1                34
# 5            2587               33                2                35
# 6            2655               17                5                22
# 7            3533               11                3                14
#
#    Avg Lines/Scene  Avg Speeches/Scene  Avg Lines/Speech
# 0           238.78               55.33              4.32
# 1           198.90               55.80              3.56
# 2            84.75               23.11              3.67
# 3           128.33               34.83              3.68
# 4            84.12               27.79              3.03
# 5           143.72               43.83              3.28
# 6           132.75               31.80              4.17
# 7           235.53               78.07              3.02

# %%
import os
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

def plot_play_network_centrality(
    play_name: str,
    csv_dir: str = "../csv",
    out_dir: str = "../figures",
    label_top_n: int = 12,
    layout: str = "spring",
    seed: int = 42,
    max_nodes: int = 30  # New parameter to filter network size
):
    """
    Enhanced network visualization with betweenness centrality.
    - Node size & color ~ betweenness centrality
    - Edge width ~ scenes shared
    - Labels: top-N by centrality
    - Improved colors, spacing, and visual hierarchy
    - Reduced node overlap through filtering and better layouts
    """
    os.makedirs(out_dir, exist_ok=True)
    net_path = os.path.join(csv_dir, f"{play_name}_network.csv")
    
    if not os.path.exists(net_path):
        print(f"Missing file: {net_path}")
        return
    
    df = pd.read_csv(net_path)
    
    # --- Build graph ---
    G = nx.Graph()
    for _, row in df.iterrows():
        a, b, w = str(row["Character A"]).strip(), str(row["Character B"]).strip(), int(row["Scenes Together"])
        if a and b and a != b:
            G.add_edge(a, b, weight=w)
    
    if G.number_of_nodes() == 0:
        print(f"No nodes for {play_name}. Skipping.")
        return
    
    # --- Calculate centrality on full graph ---
    centrality = nx.betweenness_centrality(G, normalized=True, endpoints=True)
    
    # --- Filter to top N characters by centrality to reduce overlap ---
    if G.number_of_nodes() > max_nodes:
        top_chars = sorted(centrality, key=centrality.get, reverse=True)[:max_nodes]
        G = G.subgraph(top_chars).copy()
        print(f"Filtered to top {max_nodes} characters by centrality")
    
    # --- Layout with better spacing ---
    if layout == "kamada":
        pos = nx.kamada_kawai_layout(G)
    elif layout == "spectral":
        pos = nx.spectral_layout(G)
    else:  # spring
        # Increased k for more spacing, more iterations for better convergence
        pos = nx.spring_layout(G, k=4.0, iterations=1000, seed=seed)
    
    # --- Metrics (recalculate for filtered graph) ---
    centrality_filtered = {n: centrality[n] for n in G.nodes()}
    
    # Enhanced node size calculation with reduced maximum size
    max_cent = max(centrality_filtered.values())
    min_cent = min(centrality_filtered.values())
    cent_range = max_cent - min_cent if max_cent > min_cent else 1
    
    # Reduced size range to minimize overlap (was 500-5500, now 300-3300)
    node_sizes = [300 + 3000 * ((centrality_filtered[n] - min_cent) / cent_range) ** 0.7 for n in G.nodes()]
    node_colors = [centrality_filtered[n] for n in G.nodes()]
    
    # Enhanced edge width calculation
    edge_weights = [d["weight"] for _, _, d in G.edges(data=True)]
    max_weight = max(edge_weights)
    min_weight = min(edge_weights)
    weight_range = max_weight - min_weight if max_weight > min_weight else 1
    edge_widths = [0.3 + 2.5 * ((w - min_weight) / weight_range) for w in edge_weights]
    
    # --- Plot with improved styling ---
    fig, ax = plt.subplots(figsize=(14, 10), facecolor='white')
    ax.set_facecolor('#fafafa')
    
    # Title with better formatting
    title = play_name.replace("_", " ").title()
    ax.set_title(title, fontsize=20, pad=20, fontweight='bold', family='serif')
    
    # Draw edges with gradient transparency based on weight
    edge_alphas = [0.1 + 0.4 * ((w - min_weight) / weight_range) for w in edge_weights]
    for (u, v, d), width, alpha in zip(G.edges(data=True), edge_widths, edge_alphas):
        nx.draw_networkx_edges(
            G, pos, 
            edgelist=[(u, v)],
            width=width, 
            alpha=alpha, 
            edge_color='#404040',
            ax=ax
        )
    
    # Draw nodes with improved colormap and styling
    nodes = nx.draw_networkx_nodes(
        G, pos,
        node_size=node_sizes,
        node_color=node_colors,
        cmap=plt.cm.viridis,  # Better colormap than 'cool'
        edgecolors='white',
        linewidths=2.5,
        alpha=0.95,
        ax=ax
    )
    
    # --- Enhanced labels for top-N by centrality ---
    top_nodes = sorted(centrality_filtered, key=centrality_filtered.get, reverse=True)[:label_top_n]
    
    # Create labels dictionary
    labels = {n: n for n in top_nodes}
    
    # Draw labels with improved styling
    for node, (x, y) in pos.items():
        if node in labels:
            # Determine font size based on centrality
            font_size = 9 + 4 * (centrality_filtered[node] / max_cent)
            font_weight = 'bold' if centrality_filtered[node] > max_cent * 0.5 else 'semibold'
            
            ax.text(
                x, y, node,
                fontsize=font_size,
                fontweight=font_weight,
                ha='center',
                va='center',
                bbox=dict(
                    facecolor='white',
                    edgecolor='none',
                    alpha=0.85,
                    boxstyle='round,pad=0.4'
                ),
                zorder=1000
            )
    
    # --- Enhanced Colorbar ---
    sm = plt.cm.ScalarMappable(
        cmap=plt.cm.viridis,
        norm=plt.Normalize(vmin=min(node_colors), vmax=max(node_colors))
    )
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.6, aspect=20, pad=0.02)
    cbar.set_label("Betweenness Centrality", fontsize=12, fontweight='semibold')
    cbar.ax.tick_params(labelsize=10)
    
    # Add subtle grid for reference
    ax.grid(True, alpha=0.1, linestyle='--', linewidth=0.5)
    ax.axis("off")
    
    fig.tight_layout()
    
    out_path = os.path.join(out_dir, f"{play_name}_network_centrality.png")
    plt.savefig(out_path, dpi=300, bbox_inches="tight", facecolor='white')
    plt.close()
    
    print(f"Saved: {out_path}")
    
    # Print top characters for reference
    print(f"\nTop {label_top_n} characters by betweenness centrality:")
    for i, node in enumerate(top_nodes, 1):
        print(f"  {i}. {node}: {centrality_filtered[node]:.4f}")


# Example usage
if __name__ == "__main__":
    works = [
        "the_tragedy_of_romeo_and_juliet",
        "the_tragedy_of_macbeth",
        "the_tragedy_of_hamlet,_prince_of_denmark",
        "a_midsummer_night's_dream",
        "the_tragedy_of_othello,_the_moor_of_venice",
        "the_tragedy_of_julius_caesar",
        "the_tragedy_of_antony_and_cleopatra",
        "the_merchant_of_venice"
    ]

    for w in works:
        plot_play_network_centrality(
            play_name=w,
            csv_dir="../csv",
            out_dir="./figures",
            label_top_n=15,
            layout="spring",  
            seed=42,
            max_nodes=15  # Filter to top n characters
        )
# Out:
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_romeo_and_juliet_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. CAPULET: 0.1674
#   2. ROMEO: 0.1650
#   3. LADY CAPULET: 0.1639
#   4. FRIAR LAURENCE: 0.1416
#   5. NURSE: 0.0919
#   6. PARIS: 0.0914
#   7. BENVOLIO: 0.0861
#   8. PRINCE: 0.0857
#   9. MONTAGUE: 0.0857
#   10. JULIET: 0.0832
#   11. TYBALT: 0.0782
#   12. BALTHASAR: 0.0750
#   13. PETER: 0.0682
#   14. MERCUTIO: 0.0626
#   15. FIRST CITIZEN: 0.0619
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_macbeth_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. MACBETH: 0.2859
#   2. LENNOX: 0.1985
#   3. ROSS: 0.1712
#   4. LADY MACBETH: 0.1303
#   5. BANQUO: 0.1275
#   6. MACDUFF: 0.0980
#   7. MALCOLM: 0.0936
#   8. FIRST MURDERER: 0.0922
#   9. ALL: 0.0781
#   10. DOCTOR: 0.0663
#   11. ANGUS: 0.0633
#   12. MESSENGER: 0.0591
#   13. SIWARD: 0.0586
#   14. MENTEITH: 0.0579
#   15. FIRST WITCH: 0.0534
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_hamlet,_prince_of_denmark_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. HORATIO: 0.2712
#   2. QUEEN GERTRUDE: 0.1478
#   3. HAMLET: 0.1375
#   4. KING CLAUDIUS: 0.1352
#   5. LORD POLONIUS: 0.1011
#   6. LAERTES: 0.0995
#   7. ALL: 0.0984
#   8. OPHELIA: 0.0911
#   9. ROSENCRANTZ: 0.0743
#   10. PRINCE FORTINBRAS: 0.0669
#   11. MARCELLUS: 0.0658
#   12. BERNARDO: 0.0629
#   13. VOLTIMAND: 0.0599
#   14. GUILDENSTERN: 0.0581
#   15. FIRST PLAYER: 0.0581
# Filtered to top 15 characters by centrality
# Saved: ./figures/a_midsummer_night's_dream_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. BOTTOM: 0.1683
#   2. PUCK: 0.1651
#   3. TITANIA: 0.1425
#   4. DEMETRIUS: 0.0921
#   5. LYSANDER: 0.0921
#   6. OBERON: 0.0921
#   7. COBWEB: 0.0851
#   8. MUSTARDSEED: 0.0851
#   9. PEASEBLOSSOM: 0.0851
#   10. HIPPOLYTA: 0.0787
#   11. THESEUS: 0.0787
#   12. HELENA: 0.0728
#   13. HERMIA: 0.0728
#   14. QUINCE: 0.0694
#   15. SNOUT: 0.0694
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_othello,_the_moor_of_venice_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. IAGO: 0.2254
#   2. OTHELLO: 0.1910
#   3. DESDEMONA: 0.1582
#   4. RODERIGO: 0.1457
#   5. CASSIO: 0.1171
#   6. EMILIA: 0.1003
#   7. MONTANO: 0.0802
#   8. BRABANTIO: 0.0769
#   9. FIRST OFFICER: 0.0769
#   10. CLOWN: 0.0762
#   11. BIANCA: 0.0755
#   12. GRATIANO: 0.0748
#   13. LODOVICO: 0.0748
#   14. ALL: 0.0741
#   15. DUKE OF VENICE: 0.0741
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_julius_caesar_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. BRUTUS: 0.2860
#   2. ANTONY: 0.1778
#   3. CASSIUS: 0.1358
#   4. SERVANT: 0.0654
#   5. LUCILIUS: 0.0649
#   6. MESSALA: 0.0541
#   7. LUCIUS: 0.0512
#   8. CASCA: 0.0470
#   9. CINNA: 0.0459
#   10. OCTAVIUS: 0.0455
#   11. SECOND CITIZEN: 0.0451
#   12. THIRD CITIZEN: 0.0451
#   13. FIRST CITIZEN: 0.0451
#   14. FOURTH CITIZEN: 0.0451
#   15. TREBONIUS: 0.0397
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_tragedy_of_antony_and_cleopatra_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. MARK ANTONY: 0.1943
#   2. DOMITIUS ENOBARBUS: 0.1605
#   3. OCTAVIUS CAESAR: 0.1605
#   4. CLEOPATRA: 0.1358
#   5. ALL: 0.1167
#   6. CHARMIAN: 0.0722
#   7. MENAS: 0.0692
#   8. POMPEY: 0.0692
#   9. IRAS: 0.0548
#   10. MESSENGER: 0.0507
#   11. DOLABELLA: 0.0491
#   12. AGRIPPA: 0.0462
#   13. SECOND GUARD: 0.0437
#   14. FIRST GUARD: 0.0437
#   15. PROCULEIUS: 0.0432
# Filtered to top 15 characters by centrality
# Saved: ./figures/the_merchant_of_venice_network_centrality.png
#
# Top 15 characters by betweenness centrality:
#   1. PORTIA: 0.2431
#   2. BASSANIO: 0.1654
#   3. GRATIANO: 0.1654
#   4. NERISSA: 0.1601
#   5. SHYLOCK: 0.1408
#   6. LAUNCELOT: 0.1306
#   7. LORENZO: 0.1156
#   8. SERVANT: 0.1111
#   9. SALARINO: 0.1097
#   10. JESSICA: 0.1094
#   11. ANTONIO: 0.1055
#   12. SALANIO: 0.1052
#   13. SALERIO: 0.0929
#   14. ALL: 0.0870
#   15. CLERK: 0.0870

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_all_scene_dominance(
    csv_dir: str = "../csv",
    out_dir: str = "./figures",
    top_n: int = 6,
    normalize: bool = False
):
    """
    Generates scene-level dominance plots for all <play>_speeches.csv files in csv_dir.
    Saves each figure to out_dir as a PNG.
    """
    os.makedirs(out_dir, exist_ok=True)
    speech_files = [f for f in os.listdir(csv_dir) if f.endswith("_speeches.csv")]

    for f in speech_files:
        path = os.path.join(csv_dir, f)
        df = pd.read_csv(path)

        if df.empty:
            continue

        # --- Aggregate total lines per scene/character
        scene_summary = (
            df.groupby(["Act", "Scene", "Character"], as_index=False)["Line Count"]
              .sum()
              .rename(columns={"Line Count": "Total Lines"})
        )

        # Pick top N talkers
        total_lines = (
            scene_summary.groupby("Character")["Total Lines"]
            .sum()
            .sort_values(ascending=False)
        )
        top_chars = total_lines.head(top_n).index

        plot_df = scene_summary[scene_summary["Character"].isin(top_chars)].copy()

        # Normalize if requested
        if normalize:
            scene_totals = plot_df.groupby(["Act", "Scene"])["Total Lines"].transform("sum")
            plot_df["Line Share (%)"] = plot_df["Total Lines"] / scene_totals * 100
            y_col = "Line Share (%)"
            y_label = "Share of Scene Dialogue (%)"
        else:
            y_col = "Total Lines"
            y_label = "Dialogue Lines"

        # Combine Act.Scene for x-axis
        plot_df["Scene ID"] = plot_df["Act"].astype(str) + "." + plot_df["Scene"].astype(str)

        # --- Plot ---
        plt.figure(figsize=(12, 6))
        sns.lineplot(
            data=plot_df,
            x="Scene ID", y=y_col,
            hue="Character",
            marker="o", linewidth=2, alpha=0.9
        )

        title = f.replace("_speeches.csv", "").replace("_", " ").title()
        plt.title(f"{title} — Character Dialogue Over Scenes", fontsize=14, pad=12)
        plt.xlabel("Scene (Act.Scene)")
        plt.ylabel(y_label)
        plt.xticks(rotation=45, ha="right")
        plt.grid(True, alpha=0.3)
        plt.legend(title="Character", bbox_to_anchor=(1.05, 1), loc="upper left")
        plt.tight_layout()

        out_path = os.path.join(out_dir, f.replace("_speeches.csv", "_scene_dominance.png"))
        plt.savefig(out_path, dpi=300, bbox_inches="tight")
        plt.close()
        print(f"Saved {out_path}")


plot_all_scene_dominance(csv_dir="../csv", out_dir="./figures", top_n=4, normalize=False)
# Out:
# Saved ./figures/the_tragedy_of_antony_and_cleopatra_scene_dominance.png
# Saved ./figures/the_merchant_of_venice_scene_dominance.png
# Saved ./figures/the_tragedy_of_othello,_the_moor_of_venice_scene_dominance.png
# Saved ./figures/the_tragedy_of_hamlet,_prince_of_denmark_scene_dominance.png
# Saved ./figures/a_midsummer_nights_dream_scene_dominance.png
# Saved ./figures/the_tragedy_of_romeo_and_juliet_scene_dominance.png
# Saved ./figures/the_tragedy_of_julius_caesar_scene_dominance.png
# Saved ./figures/the_tragedy_of_macbeth_scene_dominance.png

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt

def plot_character_clustering(csv_file="../csv/all_plays_character_stats.csv"):
    """
    Simple 2D clustering visualization using PCA on character quantitative features.
    """
    df = pd.read_csv(csv_file)

    # Choose relevant numeric features
    features = [
        "total_speeches", "total_lines", "scenes_appeared",
        "acts_appeared", "verbosity", "talkativeness",
        "dominance", "focus", "breadth"
    ]
    X = df[features].fillna(0)

    # Scale features
    X_scaled = StandardScaler().fit_transform(X)

    # PCA for dimensionality reduction
    pca = PCA(n_components=2)
    coords = pca.fit_transform(X_scaled)
    df["PC1"], df["PC2"] = coords[:, 0], coords[:, 1]

    # Plot
    plt.figure(figsize=(9, 7))
    sns.scatterplot(
        data=df, x="PC1", y="PC2", hue="play",
        alpha=0.7, s=70, palette="tab10"
    )
    plt.title("Character Clustering by Quantitative Features (PCA)", fontsize=14)
    plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)")
    plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_character_clustering("../csv/all_plays_char_stats.csv")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import umap.umap_ as umap
from scipy.spatial import ConvexHull

def cluster_main_characters_umap_kmeans(
    csv_file="../csv/all_plays_char_stats.csv",
    n_clusters=8,
    n_neighbors=8,
    min_dist=0.3,
    label_top_n=10,
    random_state=42,
    draw_hulls=True
):
    """
    Cluster MAIN characters using UMAP + KMeans.
    - Each point = main character
    - Color = cluster (potential archetype group)
    - Labels = top-N most talkative characters (with play names)
    - Optionally draws convex hulls for clarity
    """
    df = pd.read_csv(csv_file)

    # --- Filter main characters ---
    if "role_type" not in df.columns:
        raise ValueError("CSV must include a 'Role Type' column.")
    df_main = df[df["role_type"].str.lower() == "main"].copy()

    if df_main.empty:
        print("No main characters found.")
        return

    # --- Select reduced feature set (less correlated) ---
    features = ["total_lines", 
                "dominance", 
                "verbosity", 
                "breadth", 
                "focus"]
    X = df_main[features].fillna(0).copy()

    # --- Log-transform skewed features ---
    for col in ["total_lines", "dominance"]:
        X[col] = np.log1p(X[col])

    # --- Scale ---
    X_scaled = StandardScaler().fit_transform(X)

    # --- Dimensionality reduction (UMAP) ---
    reducer = umap.UMAP(
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        random_state=random_state
    )
    coords = reducer.fit_transform(X_scaled)
    df_main["UMAP1"], df_main["UMAP2"] = coords[:, 0], coords[:, 1]

    # --- Clustering (KMeans) ---
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
    df_main["cluster"] = kmeans.fit_predict(X_scaled)

    # --- Plot ---
    plt.figure(figsize=(9, 7))
    sns.scatterplot(
        data=df_main,
        x="UMAP1", y="UMAP2",
        hue="cluster", palette="tab10",
        s=90, alpha=0.9
    )

    plt.title("Main Character Clustering (UMAP + KMeans)", fontsize=14)
    plt.xlabel("UMAP Dimension 1")
    plt.ylabel("UMAP Dimension 2")
    plt.grid(alpha=0.3)

    # --- Optional: convex hulls for clarity ---
    if draw_hulls:
        for cluster in df_main["cluster"].unique():
            pts = df_main[df_main["cluster"] == cluster][["UMAP1", "UMAP2"]].values
            if len(pts) > 2:
                hull = ConvexHull(pts)
                plt.fill(
                    pts[hull.vertices, 0], pts[hull.vertices, 1],
                    alpha=0.08, color="gray"
                )

    # --- Label key characters (with play names) ---
    top_chars = df_main.nlargest(label_top_n, "total_lines")
    for _, row in top_chars.iterrows():
        label = f"{row['character']} ({row['play']})"
        plt.text(
            row["UMAP1"], row["UMAP2"], label,
            fontsize=8.5, weight="bold",
            ha="center", va="center",
            bbox=dict(facecolor="white", edgecolor="none", alpha=0.7, boxstyle="round,pad=0.2")
        )

    plt.tight_layout()
    plt.show()

    # --- Print cluster summary with play names ---
    print("\nCluster summary (top 5 main characters per cluster)\n\n")
    for cluster in sorted(df_main["cluster"].unique()):
        chars = (
            df_main[df_main["cluster"] == cluster]
            .nlargest(5, "total_lines")[["character", "play"]]
            .apply(lambda r: f"{r['character']} ({r['play']})", axis=1)
            .tolist()
        )
        print(f"  Cluster {cluster}: \n{',\n'.join(chars)}")
        print()

    return df_main

# Run your existing function (as you did)
clustered_df = cluster_main_characters_umap_kmeans(
    csv_file="../csv/all_plays_char_stats.csv",
    n_clusters=8,
    n_neighbors=10,
    min_dist=0.8,
    label_top_n=0
)

# # --- Merge the new cluster info back into the full CSV ---
# # Load the original file
# df_all = pd.read_csv("../csv/all_plays_char_stats.csv")

# # Merge cluster assignments back (only for main characters)
# df_all = df_all.merge(
#     clustered_df[["character", "play", "cluster"]],
#     on=["character", "play"],
#     how="left"
# )

# # Save the updated version
# df_all.to_csv("../csv/all_plays_char_stats_with_clusters.csv", index=False)

# print("Saved updated CSV with Cluster column as '../csv/all_plays_char_stats_with_clusters.csv'")
# Out:
# /Users/jazzydelossantos/Desktop/CalPoly/fall-qtr-25/csc466_finalproj/.venv/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Cluster summary (top 5 main characters per cluster)
#
#
#   Cluster 0:
# OCTAVIUS CAESAR (The Tragedy of Antony and Cleopatra),
# DOMITIUS ENOBARBUS (The Tragedy of Antony and Cleopatra),
# SHYLOCK (The Merchant of Venice),
# FRIAR LAURENCE (The Tragedy of Romeo and Juliet),
# BASSANIO (The Merchant of Venice)
#
#   Cluster 1:
# EGEUS (A Midsummer Night's Dream),
# MONTAGUE (The Tragedy of Romeo and Juliet),
# MARULLUS (The Tragedy of Julius Caesar),
# VENTIDIUS (The Tragedy of Antony and Cleopatra),
# CALPURNIA (The Tragedy of Julius Caesar)
#
#   Cluster 2:
# HAMLET (The Tragedy of Hamlet, Prince of Denmark),
# IAGO (The Tragedy of Othello, the Moor of Venice),
# OTHELLO (The Tragedy of Othello, the Moor of Venice),
# MARK ANTONY (The Tragedy of Antony and Cleopatra)
#
#   Cluster 3:
# DESDEMONA (The Tragedy of Othello, the Moor of Venice),
# HORATIO (The Tragedy of Hamlet, Prince of Denmark),
# CASSIO (The Tragedy of Othello, the Moor of Venice),
# EMILIA (The Tragedy of Othello, the Moor of Venice),
# LAERTES (The Tragedy of Hamlet, Prince of Denmark)
#
#   Cluster 4:
# LADY CAPULET (The Tragedy of Romeo and Juliet),
# CHARMIAN (The Tragedy of Antony and Cleopatra),
# LODOVICO (The Tragedy of Othello, the Moor of Venice),
# LENNOX (The Tragedy of Macbeth),
# DUKE OF VENICE (The Tragedy of Othello, the Moor of Venice)
#
#   Cluster 5:
# REYNALDO (The Tragedy of Hamlet, Prince of Denmark),
# MENTEITH (The Tragedy of Macbeth),
# TUBAL (The Merchant of Venice),
# FRANCISCO (The Tragedy of Hamlet, Prince of Denmark),
# CLITUS (The Tragedy of Julius Caesar)
#
#   Cluster 6:
# HECATE (The Tragedy of Macbeth)
#
#   Cluster 7:
# MACBETH (The Tragedy of Macbeth),
# CLEOPATRA (The Tragedy of Antony and Cleopatra),
# ROMEO (The Tragedy of Romeo and Juliet),
# PORTIA (The Merchant of Venice),
# JULIET (The Tragedy of Romeo and Juliet)

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

df = pd.read_csv("../csv/the_tragedy_of_romeo_and_juliet_speeches.csv")

# Example: df has a column "lines" containing all of a character’s dialogue concatenated as a string
sia = SentimentIntensityAnalyzer()

# Apply sentiment analyzer
df['sentiment'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['compound'])

# Optional: split into more detail
df['sent_pos'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['pos'])
df['sent_neg'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['neg'])
df['sent_neu'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['neu'])

# df.groupby('Character')['sentiment'].mean()
df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jazzydelossantos/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                 Play  Act  Scene Character  Line Count  \
# 0    The Tragedy of Romeo and Juliet    1      1   SAMPSON           8
# 1    The Tragedy of Romeo and Juliet    1      1   GREGORY           7
# 2    The Tragedy of Romeo and Juliet    1      1   SAMPSON           9
# 3    The Tragedy of Romeo and Juliet    1      1   GREGORY          11
# 4    The Tragedy of Romeo and Juliet    1      1   SAMPSON           5
# ..                               ...  ...    ...       ...         ...
# 829  The Tragedy of Romeo and Juliet    5      3    PRINCE          85
# 830  The Tragedy of Romeo and Juliet    5      3   CAPULET          18
# 831  The Tragedy of Romeo and Juliet    5      3  MONTAGUE          39
# 832  The Tragedy of Romeo and Juliet    5      3   CAPULET          13
# 833  The Tragedy of Romeo and Juliet    5      3    PRINCE          49
#
#                                                   Text  sentiment  sent_pos  \
# 0          Gregory, o' my word, we'll not carry coals.     0.0000     0.000
# 1                  No, for then we should be colliers.    -0.2960     0.000
# 2              I mean, an we be in choler, we'll draw.     0.0000     0.000
# 3    Ay, while you live, draw your neck out o' the ...     0.0000     0.000
# 4                       I strike quickly, being moved.    -0.1280     0.000
# ..                                                 ...        ...       ...
# 829  This letter doth make good the friar's words, ...    -0.9018     0.157
# 830  O brother Montague, give me thy hand: This is ...     0.0571     0.159
# 831  But I can give thee more: For I will raise her...     0.6956     0.170
# 832  As rich shall Romeo's by his lady's lie; Poor ...     0.2003     0.216
# 833  A glooming peace this morning with it brings; ...    -0.8977     0.058
#
#      sent_neg  sent_neu
# 0       0.000     1.000
# 1       0.268     0.732
# 2       0.000     1.000
# 3       0.000     1.000
# 4       0.333     0.667
# ..        ...       ...
# 829     0.254     0.589
# 830     0.197     0.644
# 831     0.063     0.767
# 832     0.172     0.611
# 833     0.257     0.685
#
# [834 rows x 10 columns]

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
import glob

nltk.download('vader_lexicon')

stats_df = pd.read_csv("../csv/all_plays_char_stats.csv")
sia = SentimentIntensityAnalyzer()

# Get all lines CSVs
all_sentiments = []

for filepath in glob.glob("../csv/*_lines.csv"):
    df = pd.read_csv(filepath)
    
    # Calculate sentiment scores
    df['sentiment'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['compound'])
    df['sent_pos'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['pos'])
    df['sent_neg'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['neg'])
    df['sent_neu'] = df['Text'].apply(lambda text: sia.polarity_scores(str(text))['neu'])
    
    # Get mean sentiment per play/character
    char_sentiment = df.groupby(['Play', 'Character']).agg({
        'sentiment': 'mean',
        'sent_pos': 'mean',
        'sent_neg': 'mean',
        'sent_neu': 'mean'
    }).reset_index()
    
    all_sentiments.append(char_sentiment)
    print(f"Processed {filepath}")

# Combine all sentiments
combined_sentiment = pd.concat(all_sentiments, ignore_index=True)
combined_sentiment = combined_sentiment.rename(columns={'Play': 'play', 'Character': 'character'})

# Merge into stats dataframe
stats_df = stats_df.merge(combined_sentiment, on=['play', 'character'], how='left')

# Save updated stats
stats_df.to_csv("../csv/all_plays_char_stats.csv", index=False)

print(stats_df)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jazzydelossantos/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Processed ../csv/the_tragedy_of_hamlet,_prince_of_denmark_lines.csv
# Processed ../csv/a_midsummer_nights_dream_lines.csv
# Processed ../csv/the_tragedy_of_romeo_and_juliet_lines.csv
# Processed ../csv/the_tragedy_of_macbeth_lines.csv
# Processed ../csv/the_tragedy_of_antony_and_cleopatra_lines.csv
# Processed ../csv/the_merchant_of_venice_lines.csv
# Processed ../csv/the_tragedy_of_julius_caesar_lines.csv
# Processed ../csv/the_tragedy_of_othello,_the_moor_of_venice_lines.csv
#                                            play         character  \
# 0                     A Midsummer Night's Dream           THESEUS
# 1                     A Midsummer Night's Dream            HELENA
# 2                     A Midsummer Night's Dream            OBERON
# 3                     A Midsummer Night's Dream              PUCK
# 4                     A Midsummer Night's Dream            BOTTOM
# ..                                          ...               ...
# 289  The Tragedy of Othello, the Moor of Venice  FOURTH GENTLEMAN
# 290  The Tragedy of Othello, the Moor of Venice  SECOND GENTLEMEN
# 291  The Tragedy of Othello, the Moor of Venice           SENATOR
# 292  The Tragedy of Othello, the Moor of Venice               ALL
# 293  The Tragedy of Othello, the Moor of Venice         GENTLEMAN
#
#      total_speeches  total_lines  scenes_appeared  acts_appeared  \
# 0                48          233                3              3
# 1                36          229                5              4
# 2                29          226                5              4
# 3                33          209                6              4
# 4                50          204                5              4
# ..              ...          ...              ...            ...
# 289               1            2                1              1
# 290               1            2                1              1
# 291               2            2                1              1
# 292               2            2                2              2
# 293               1            1                1              1
#
#      speech_share_pct  line_share_pct  avg_speeches_per_scene  \
# 0                9.60           10.79                    16.0
# 1                7.20           10.61                     7.2
# 2                5.80           10.47                     5.8
# 3                6.60            9.68                     5.5
# 4               10.00            9.45                    10.0
# ..                ...             ...                     ...
# 289              0.08            0.06                     1.0
# 290              0.08            0.06                     1.0
# 291              0.17            0.06                     2.0
# 292              0.17            0.06                     1.0
# 293              0.08            0.03                     1.0
#
#      avg_lines_per_speech  ...  play_total_acts  play_total_scenes  \
# 0                    4.85  ...                5                  9
# 1                    6.36  ...                5                  9
# 2                    7.79  ...                5                  9
# 3                    6.33  ...                5                  9
# 4                    4.08  ...                5                  9
# ..                    ...  ...              ...                ...
# 289                  2.00  ...                5                 15
# 290                  2.00  ...                5                 15
# 291                  1.00  ...                5                 15
# 292                  1.00  ...                5                 15
# 293                  1.00  ...                5                 15
#
#      play_total_speeches  play_total_lines  main_side_ratio  role_type  \
# 0                    500              2159             21:2       main
# 1                    500              2159             21:2       main
# 2                    500              2159             21:2       main
# 3                    500              2159             21:2       main
# 4                    500              2159             21:2       main
# ..                   ...               ...              ...        ...
# 289                 1183              3558             11:3       side
# 290                 1183              3558             11:3       side
# 291                 1183              3558             11:3       side
# 292                 1183              3558             11:3       side
# 293                 1183              3558             11:3       side
#
#      sentiment  sent_pos  sent_neg  sent_neu
# 0     0.083028  0.146341  0.088030  0.765634
# 1     0.046412  0.143825  0.113389  0.742786
# 2     0.077727  0.114920  0.056684  0.828391
# 3     0.009942  0.085895  0.076278  0.837833
# 4     0.108073  0.135512  0.062831  0.801647
# ..         ...       ...       ...       ...
# 289  -0.363900  0.000000  0.232500  0.767500
# 290   0.418950  0.401000  0.000000  0.599000
# 291  -0.399950  0.000000  0.642500  0.357500
# 292   0.578850  0.874500  0.000000  0.125500
# 293   0.000000  0.000000  0.000000  1.000000
#
# [294 rows x 25 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS

# Load line-level CSV
spoken_lines = pd.read_csv("../csv/the_tragedy_of_romeo_and_juliet_lines.csv")

# Combine all lines spoken by each character into a single document
char_texts = (
    spoken_lines.groupby("Character")["Text"]
    .apply(lambda lines: " ".join(lines))
    .reset_index()
)

custom_stop_words = "thou", "thy", "thee", "ll"
combined_stop_words = set(ENGLISH_STOP_WORDS).union(custom_stop_words)

# Initialize vectorizer
vect = TfidfVectorizer(
    lowercase=True,
    stop_words=list(combined_stop_words),  # optional
    ngram_range=(1, 2),    # unigrams + bigrams if you like
    max_df=0.9,
    min_df=2
)

# Fit-transform the combined character text
tfidf_matrix = vect.fit_transform(char_texts["Text"])

# Get feature names (words)
feature_names = vect.get_feature_names_out()

# Convert to a DataFrame
tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    index=char_texts["Character"],
    columns=feature_names
)

# Example: show top 10 words per character
def top_terms_for_character(character, n=10):
    row = tfidf_df.loc[character]
    top_terms = row.sort_values(ascending=False).head(n)
    return top_terms

# Example usage
print(top_terms_for_character("ROMEO"))
print(top_terms_for_character("JULIET"))
print(top_terms_for_character("TYBALT"))
# Out:
# love        0.437732
# death       0.171210
# beauty      0.142429
# dear        0.138326
# fair        0.137546
# juliet      0.134687
# night       0.126269
# eyes        0.124854
# farewell    0.117045
# man         0.112467
# Name: ROMEO, dtype: float64
# romeo     0.297492
# love      0.295615
# night     0.253384
# shall     0.203119
# nurse     0.202474
# come      0.174142
# sweet     0.154182
# st        0.132092
# tybalt    0.118246
# good      0.117808
# Name: JULIET, dtype: float64
# villain      0.279440
# hate         0.234220
# boy          0.221017
# scorn        0.195725
# consort      0.195725
# solemnity    0.195725
# drawn        0.195725
# uncle        0.179299
# shall        0.155739
# romeo        0.150211
# Name: TYBALT, dtype: float64
